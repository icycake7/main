# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
import numpy as np
import pandas as pd
from time import sleep
from random import randint

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Set url
url = 'https://sfbay.craigslist.org/search/sfc/apa#search=1~thumb~0~0'
browser.visit(url)

# Parse the HTML
html = browser.html
soup = bs(html, 'html.parser')

# find and extract relevant data
search = soup.find_all('div', class_='result-info')

# Create empty list to store scraped data
datatoget = []

# Loop through data found and extract relevant information
for (counter,link) in enumerate(search):

#     if counter == 2:
#         break
    # scrape dates
    dates = link.find_all('div', class_='meta')[0].text.split()[0][:5]

    # scrape titles
    titles = link.find_all('a', class_='titlestring')[0].text

    # scrape links
    links = link.find_all('a', class_='titlestring', href=True)[0]['href']

    # scrape prices
    prices = link.find_all('span', class_='priceinfo')[0].text

    # scrape neighborhoods
    neighborhoods = link.find('div', class_='supertitle').text

    # error handeling in case there are no bedrooms displayed
    try:
        bedrooms = link.find('span', class_='post-bedrooms').text

    except:
        bedrooms = np.nan

    # error handeling in case there are no sqft displayed
    try:
        sqft = link.find('span', class_='post-sqft').text.split()[0][:-3]
    except:
        sqft = np.nan
    
    # ensures that the server does not get overloaded with requests
    sleep(randint(1,5))  
    
    # visit each link seperately
    browser.visit(links)

    # after visiting link, extract bath and amenities data
    html = browser.html
    soup = bs(html, 'html.parser')
    baths = soup.find_all('p', class_='attrgroup')[0].text.split('\n')[1].split()[2][:-2]

    
    amenities = soup.find_all('p', class_='attrgroup')[1].text.split('\n')
    all_amenities = [am for am in amenities if len(am) >= 1]
    
    # print statements to ensure that the correct data is scraped
    print(sqft)
    print(prices)
    print(titles)
    print(dates)
    print(bedrooms)
    print(neighborhoods)
    print(baths)
    print(counter)
    print(links)
    print(all_amenities)

    # create dicitonary for our DataFrame
    data = {'date': dates,
            'title': titles,
            'link': links,
            'price': prices,
            'bedroom': bedrooms,
            'sqft': sqft,
            'neighborhood': neighborhoods,
            'bathroom': baths,
            'amenities': all_amenities}
    
    # append the data
    datatoget.append(data)
# Out:
# 920
# $3,985
# 2 bdr. with awesome City view
# 12/31
# 2br
# cole valley / ashbury hts
# 1
# 0
# https://sfbay.craigslist.org/sfc/apa/7573487609.html
# ['cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'street parking', 'rent period: monthly']
# 745
# $3,961
# Skybox lounge, Valet parking, Reception lobby bar and café
# 12/31
# 1br
# SOMA / south beach
# 1
# 1
# https://sfbay.craigslist.org/sfc/apa/7565465402.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 300
# $1,550
# Fourth-floor studio in Theater District
# 12/31
# nan
# lower nob hill
# 1
# 2
# https://sfbay.craigslist.org/sfc/apa/7573485201.html
# ['apartment', 'laundry in bldg', 'no smoking', 'no parking', 'rent period: monthly']
# 1146
# $7,435
# Skybox lounge, Public art plaza, Valet parking
# 12/31
# 3br
# SOMA / south beach
# 2
# 3
# https://sfbay.craigslist.org/sfc/apa/7567879622.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 1000
# $2,785
# Beautiful Landscaping, Microwave, Covered Parking
# 12/31
# 2br
# alamo square / nopa
# 1.5
# 4
# https://sfbay.craigslist.org/sfc/apa/7571564203.html
# ['air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'carport', 'rent period: monthly']
# nan
# $2,675
# TOP FLOOR Remodeled 2-bedroom unit with Parking
# 12/31
# 2br
# inner richmond
# 1
# 5
# https://sfbay.craigslist.org/sfc/apa/7564305873.html
# ['cats are OK - purrr', 'apartment', 'laundry on site', 'carport', 'rent period: monthly']
# nan
# $2,675
# TOP FLOOR Remodeled 2-bedroom unit with Parking
# 12/31
# 2br
# richmond / seacliff
# 1
# 6
# https://sfbay.craigslist.org/sfc/apa/7564301680.html
# ['cats are OK - purrr', 'apartment', 'laundry in bldg', 'carport', 'rent period: monthly']
# 1146
# $7,250
# Public art plaza, Skybox lounge, EV & scooter charging stations
# 12/31
# 3br
# SOMA / south beach
# 2
# 7
# https://sfbay.craigslist.org/sfc/apa/7564902244.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# nan
# $2,800
# Excellent location in one of the best blocks in Central Sunset
# 12/31
# 3br
# sunset / parkside
# 1
# 8
# https://sfbay.craigslist.org/sfc/apa/7563685539.html
# ['open house dates', 'saturday 2022-12-10', 'sunday 2022-12-11', 'saturday 2022-12-17']
# nan
# $2,800
# Excellent location in one of the best blocks in Central Sunset
# 12/31
# 3br
# sunset / parkside
# 1
# 9
# https://sfbay.craigslist.org/sfc/apa/7566474440.html
# ['open house dates', 'saturday 2022-12-10', 'sunday 2022-12-11', 'saturday 2022-12-17']
# 400
# $2,200
# Studio Apartment (Recently Remodeled)
# 12/31
# nan
# sunset / parkside
# 1
# 10
# https://sfbay.craigslist.org/sfc/apa/7563680936.html
# ['duplex', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly']
# 590
# $2,688
# 1Month free+ reduced deposit of  $250 When you Move in by 12/31/22
# 12/31
# 1br
# lower nob hill
# 1
# 11
# https://sfbay.craigslist.org/sfc/apa/7571160411.html
# ['apartment', 'laundry on site', 'carport', 'rent period: monthly']
# 400
# $2,200
# Studio Apartment (Recently Remodeled)
# 12/31
# nan
# sunset / parkside
# 1
# 12
# https://sfbay.craigslist.org/sfc/apa/7563682428.html
# ['duplex', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly']
# 1130
# $4,995
# Bike Storage & Repair, Public art plaza, Valet parking
# 12/31
# 2br
# SOMA / south beach
# 2
# 13
# https://sfbay.craigslist.org/sfc/apa/7568329878.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 650
# $2,160
# Awesome value! GREAT Location!
# 12/31
# 1br
# alamo square / nopa
# 1
# 14
# https://sfbay.craigslist.org/sfc/apa/7571565326.html
# ['air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'carport', 'rent period: monthly']
# 1146
# $7,250
# Bike Storage & Repair, Public art plaza, Reception lobby bar and café
# 12/31
# 3br
# SOMA / south beach
# 2
# 15
# https://sfbay.craigslist.org/sfc/apa/7571909986.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 450
# $1,750
# Top floor - very bright! * Just fully remodeled!
# 12/31
# nan
# city of san francisco
# 1
# 16
# https://sfbay.craigslist.org/sfc/apa/7573472424.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'condo', 'laundry on site', 'off-street parking', 'rent period: monthly']
# nan
# $2,000
# 两房 Mission&Geneva/Balboa BART 租
# 12/31
# 2br
# excelsior / outer mission
# 1
# 17
# https://sfbay.craigslist.org/sfc/apa/7570533113.html
# ['in-law', 'laundry on site', 'street parking', 'rent period: monthly']
# 1700
# $5,250
# 3br - 3 Bedrooms & 3 Bath Townhouse Condo
# 12/31
# 3br
# richmond / seacliff
# 3
# 18
# https://sfbay.craigslist.org/sfc/apa/7573473452.html
# ['condo', 'w/d in unit', 'no smoking', 'detached garage', 'rent period: monthly']
# 441
# $2,019
# Get 1Month free+ Reduced Deposit  When you Move in By 12/31/22
# 12/31
# nan
# lower nob hill
# 1
# 19
# https://sfbay.craigslist.org/sfc/apa/7571127897.html
# ['apartment', 'laundry on site', 'carport', 'rent period: monthly']
# nan
# $5,295
# 5 bedrooms, renovated, parking, Nice , Near hospital
# 12/31
# 5br
# potrero hill
# 3
# 20
# https://sfbay.craigslist.org/sfc/apa/7573472917.html
# ['apartment', 'laundry in bldg', 'off-street parking', 'rent period: monthly']
# nan
# $3,350
# Brand New Remodeled Unit with Vintage Edwardian charm
# 12/31
# 1br
# noe valley
# 1
# 21
# https://sfbay.craigslist.org/sfc/apa/7573472661.html
# ['apartment', 'w/d in unit', 'no parking', 'rent period: monthly']
# 1146
# $7,435
# EV & scooter charging stations, Public art plaza
# 12/31
# 3br
# SOMA / south beach
# 2
# 22
# https://sfbay.craigslist.org/sfc/apa/7566088593.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 650
# $2,150
# Newly renovated unit (2021) within steps of panoramic views of San Fra
# 12/30
# 1br
# city of san francisco
# 1
# 23
# https://sfbay.craigslist.org/sfc/apa/7573469813.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'condo', 'laundry on site', 'off-street parking', 'rent period: monthly']
# nan
# $2,900
# Sunny Corner Unit
# 12/30
# 2br
# SOMA / south beach
# 1
# 24
# https://sfbay.craigslist.org/sfc/apa/7570157113.html
# ['apartment', 'laundry in bldg', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $4,495
# GREAT NOE 3BR+2BA.HOUSE! Large,Sunny LandscYard,InUnitWD,Deck,Parking~
# 12/30
# 3br
# noe valley
# 2
# 25
# https://sfbay.craigslist.org/sfc/apa/7569595913.html
# ['application fee details: $40 - for each applicant.', 'house', 'w/d in unit', 'no smoking', 'off-street parking', 'rent period: monthly']
# 535
# $2,080
# Balcony or Patio, Cable Ready, Shimmering Swimming Pool
# 12/30
# 1br
# alamo square / nopa
# 1
# 26
# https://sfbay.craigslist.org/sfc/apa/7570416555.html
# ['apartment', 'laundry on site', 'carport', 'rent period: monthly']
# nan
# $800
# **~**Have A Nice one bedroom apartment in SF Bay Area**~**.
# 12/30
# 1br
# SOMA / south beach
# 1
# 27
# https://sfbay.craigslist.org/sfc/apa/7573463655.html
# ['apartment', 'w/d in unit', 'off-street parking', 'rent period: monthly']
# 495
# $2,500
# one bed and one den for rent
# 12/30
# 2br
# San Francisco
# 1
# 28
# https://sfbay.craigslist.org/sfc/apa/7573464818.html
# ['house', 'laundry on site', 'no smoking', 'no parking', 'rent period: monthly']
# 495
# $2,500
# couple's favorite !one bed with living room, big kitchen and  bath for rent
# 12/30
# 1br
# San Francisco
# 1
# 29
# https://sfbay.craigslist.org/sfc/apa/7573464771.html
# ['house', 'laundry on site', 'no smoking', 'street parking', 'rent period: monthly']
# nan
# $1,495
# Lovely Outer Sunset Studio by Ocean Beach and shops
# 12/30
# nan
# Outer Sunset
# 1
# 30
# https://sfbay.craigslist.org/sfc/apa/7572044866.html
# ['in-law', 'laundry on site', 'no smoking', 'street parking', 'rent period: monthly']
# 1200
# $4,395
# TOP Victorian Flat-PANO Vus! Sunny,HdWd,Yard,Patio,Deck,Storage
# 12/30
# 2br
# noe valley
# 1
# 31
# https://sfbay.craigslist.org/sfc/apa/7566311753.html
# ['application fee details: $40-Application/Job Verification', 'flat', 'laundry in bldg', 'street parking', 'rent period: monthly']
# 1000
# $3,475
# *BEST NOE LOCATION! SunnyYard/Private Patio,In-unitWD,HdWdFlrs!
# 12/30
# 2br
# noe valley
# 1
# 32
# https://sfbay.craigslist.org/sfc/apa/7569595702.html
# ['application fee details: $40 each for credit check & job verification.', 'duplex', 'w/d in unit', 'no smoking', 'street parking', 'rent period: monthly']
# nan
# $4,495
# GREAT NOE 3BR+2BA.HOUSE! Large,Sunny LandscYard,InUnitWD,Deck,Parking~
# 12/30
# 3br
# noe valley
# 2
# 33
# https://sfbay.craigslist.org/sfc/apa/7569595517.html
# ['application fee details: $40 - for each applicant.', 'house', 'w/d in unit', 'no smoking', 'off-street parking', 'rent period: monthly']
# 450
# $1,850
# One Bedroom Apartment (Sacramento & Leavenworth)
# 12/30
# 1br
# nob hill
# 1
# 34
# https://sfbay.craigslist.org/sfc/apa/7563897630.html
# ['apartment', 'no laundry on site', 'no smoking', 'no parking', 'rent period: monthly']
# 442
# $2,495
# EPIC REA-HALF MONTH FREE RENT-Bright/Beautiful 1BD/1BA w/PKG & Wash/Dr
# 12/30
# 1br
# visitacion valley
# 1
# 35
# https://sfbay.craigslist.org/sfc/apa/7573464462.html
# ['application fee details: $45 Tenant Screening and application', 'duplex', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly']
# 900
# $3,100
# EPIC REA - Beautiful 3BR/1BA lower flat unit  with a walk score 98/100
# 12/30
# 3br
# mission district
# 1
# 36
# https://sfbay.craigslist.org/sfc/apa/7573463862.html
# ['application fee details: $45 Tenant screening and application', 'duplex', 'w/d in unit', 'no smoking', 'no parking', 'rent period: monthly']
# 1325
# $3,375
# Reduced, prime Dogpatch location, Live/work Loft available
# 12/30
# 1br
# potrero hill
# 1
# 37
# https://sfbay.craigslist.org/sfc/apa/7567032856.html
# ['application fee details: $30.00 application fee per applicant', 'cats are OK - purrr', 'loft', 'laundry in bldg', 'no smoking', 'street parking', 'rent period: monthly']
# 1200
# $4,250
# EPIC REA_AZARI PM-UPDATED KITCHEN ,FLOOR ,BATHROOMS OF THIS COSY HOUSE
# 12/30
# 3br
# excelsior / outer mission
# 2
# 38
# https://sfbay.craigslist.org/sfc/apa/7571192781.html
# ['application fee details: $45 - Tenant screening and application', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 856
# $3,850
# EpicREA-AzariPM-Fabulous View 1 BR + Den or Dining/1 BA -Arterra w/Pkg
# 12/30
# 1br
# SOMA / south beach
# 1
# 39
# https://sfbay.craigslist.org/sfc/apa/7570699519.html
# ['application fee details: $45 - tenant screening & processing', 'condo', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 500
# $2,300
# EpicREA - Fabulous Modern Large Studio/ with 1 bath with Views
# 12/30
# nan
# bayview
# 1
# 40
# https://sfbay.craigslist.org/sfc/apa/7570686750.html
# ['application fee details: $45 Tenant screening and application', 'apartment', 'laundry in bldg', 'no smoking', 'no parking', 'rent period: monthly']
# 1540
# $5,995
# Epic REA -Live On Top of Nob Hill w/Views of Huntington Park
# 12/30
# 2br
# nob hill
# 2
# 41
# https://sfbay.craigslist.org/sfc/apa/7571441919.html
# ['application fee details: $45 Tenant screening and processing', 'apartment', 'w/d in unit', 'no smoking', 'no parking', 'rent period: monthly']
# 1146
# $7,435
# EV & scooter charging stations, Attended arrival desk, Skybox lounge
# 12/30
# 3br
# SOMA / south beach
# 2
# 42
# https://sfbay.craigslist.org/sfc/apa/7572239877.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 2600
# $8,990
# EXECUTIVE HOME PARKING YARD LAUNDRY CHARGER! IDEAL LOCATION!
# 12/30
# 4br
# west portal / forest hill
# 3
# 43
# https://sfbay.craigslist.org/sfc/apa/7573460723.html
# ['apartment', 'w/d in unit', 'attached garage', 'rent period: monthly']
# 750
# $2,795
# Spacious 1 bed 1 bath in the Marina
# 12/30
# 1br
# marina / cow hollow
# 1
# 44
# https://sfbay.craigslist.org/sfc/apa/7572467273.html
# ['application fee details: $40 application fee to check credit and background', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking', 'rent period: monthly']
# 400
# $1,850
# Cozy clean studio in the Marina
# 12/30
# 1br
# marina / cow hollow
# 1
# 45
# https://sfbay.craigslist.org/sfc/apa/7572744140.html
# ['application fee details: $40 application fee to check credit and background', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'street parking', 'rent period: monthly']
# 1254
# $3,900
# AMAZING! 2BR/1.5B Live/Work Loft (Parking Included!)
# 12/30
# 2br
# SOMA / south beach
# 1.5
# 46
# https://sfbay.craigslist.org/sfc/apa/7565579588.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'loft', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly']
# 1000
# $3,980
# BEAUTIFUL 2BED HOME PARKING LAUNDRY AVAILABLE! IDEAL SF LOCATION!!
# 12/30
# 2br
# inner richmond
# 1
# 47
# https://sfbay.craigslist.org/sfc/apa/7573458778.html
# ['apartment', 'laundry in bldg', 'attached garage', 'rent period: monthly']
# nan
# $2,300
# Regina Towers Apartment for Rent
# 12/30
# 1br
# lower nob hill
# 1
# 48
# https://sfbay.craigslist.org/sfc/apa/7565442839.html
# ['cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'no parking', 'rent period: monthly']
# 556
# $2,720
# Get 1month free + reduced deposit of  $250 W/ Private patio
# 12/30
# 1br
# lower nob hill
# 1
# 49
# https://sfbay.craigslist.org/sfc/apa/7572783959.html
# ['apartment', 'laundry on site', 'carport', 'rent period: monthly']
# 850
# $3,600
# Rare 2 bed/1 bath with parking, yard, w/d and the best access!
# 12/30
# 2br
# San Francisco
# 1
# 50
# https://sfbay.craigslist.org/sfc/apa/7573458101.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'furnished', 'house', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly']
# 1100
# $3,600
# Beautiful spacious two bedrooms top floor
# 12/30
# 2br
# richmond / seacliff
# 1
# 51
# https://sfbay.craigslist.org/sfc/apa/7573461268.html
# ['cats are OK - purrr', 'house', 'laundry on site', 'attached garage', 'rent period: monthly']
# 1100
# $3,600
# Beautiful spacious two bedrooms top floor
# 12/30
# 2br
# richmond / seacliff
# 1
# 52
# https://sfbay.craigslist.org/sfc/apa/7573461123.html
# ['cats are OK - purrr', 'house', 'laundry on site', 'attached garage', 'rent period: monthly']
# 1100
# $3,600
# Beautiful spacious two bedrooms top floor
# 12/30
# 2br
# richmond / seacliff
# 1
# 53
# https://sfbay.craigslist.org/sfc/apa/7570186732.html
# ['cats are OK - purrr', 'house', 'laundry on site', 'attached garage', 'rent period: monthly']
# 1200
# $5,200
# 2bd/2ba Historic North Beach Malthouse- Available Jan
# 12/30
# 2br
# north beach / telegraph hill
# 2
# 54
# https://sfbay.craigslist.org/sfc/apa/7573459034.html
# ['EV charging', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'attached garage', 'rent period: monthly']
# 1030
# $870
# Spacious 2 bedroom, 1 bathroom condo
# 12/30
# 2br
# SF bay area
# 1
# 55
# https://sfbay.craigslist.org/sfc/apa/7573451903.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'attached garage', 'rent period: monthly']
# nan
# $3,800
# Large spacious 2/3 bedroom apartment
# 12/30
# 2br
# inner richmond
# 1
# 56
# https://sfbay.craigslist.org/sfc/apa/7570548800.html
# ['apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# 800
# $3,100
# Russian Hill Apt. in Green/Hyde Sts. Neighborhood
# 12/30
# 2br
# russian hill
# 1
# 57
# https://sfbay.craigslist.org/sfc/apa/7567022272.html
# ['apartment', 'no laundry on site', 'no smoking', 'street parking', 'rent period: monthly']
# 800
# $3,000
# two bedroom / commercial space
# 12/30
# 2br
# inner richmond
# 1.5
# 58
# https://sfbay.craigslist.org/sfc/apa/7570546887.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# 596
# $3,436
# Backyard terrace with pizza oven, Bike Storage & Repair
# 12/30
# 1br
# SOMA / south beach
# 1
# 59
# https://sfbay.craigslist.org/sfc/apa/7565904358.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 955
# $3,800
# Spacious Full House in Excelsior with Parking and Abundant Storage!
# 12/30
# 3br
# excelsior / outer mission
# 1
# 60
# https://sfbay.craigslist.org/sfc/apa/7573453333.html
# ['application fee details: $50', 'cats are OK - purrr', 'dogs are OK - wooof', 'house', 'laundry on site', 'no smoking', 'attached garage', 'rent period: monthly']
# 1300
# $3,950
# Spacious and Bright 3BR Flat with Parking Available and Backyard
# 12/30
# 3br
# excelsior / outer mission
# 2
# 61
# https://sfbay.craigslist.org/sfc/apa/7573449363.html
# ['application fee details: $50', 'apartment', 'laundry on site', 'no smoking', 'attached garage', 'rent period: monthly']
# 2300
# $9,500
# SOMA Luxury Furnished Executive Retreat
# 12/30
# 1br
# SOMA / south beach
# 2.5
# 62
# https://sfbay.craigslist.org/sfc/apa/7573449709.html
# ['application fee details: $50 per adult', 'broker fee details: Lease Fee $350', 'furnished', 'condo', 'w/d in unit', 'listed by: Home 2 San Francisco', 'no parking', 'rent period: monthly']
# nan
# $4,295
# Penthouse,Top of the world, Private view deck, Fresh air, Unique+Rare
# 12/30
# 3br
# inner richmond
# 1
# 63
# https://sfbay.craigslist.org/sfc/apa/7565099786.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'street parking', 'rent period: monthly']
# 1200
# $3,800
# Bright and Spacious 2 BD 1 BA Unit for Rent! Available Now!
# 12/30
# 2br
# USF / panhandle
# 1
# 64
# https://sfbay.craigslist.org/sfc/apa/7567326532.html
# ['duplex', 'laundry in bldg', 'no smoking', 'street parking', 'rent period: monthly']
# 805
# $3,809
# Leasing Now, Yoga Studio with Spin Bikes, Walk In Closets
# 12/30
# 1br
# hayes valley
# 1
# 65
# https://sfbay.craigslist.org/sfc/apa/7573427669.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'attached garage', 'rent period: monthly']
# 400
# $2,600
# Available 2-1, quiet pet-friendly apt. on beautiful Cole Valley street
# 12/30
# 1br
# cole valley / ashbury hts
# 1
# 66
# https://sfbay.craigslist.org/sfc/apa/7573448698.html
# ['application fee details: $40 credit check', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'street parking', 'rent period: monthly']
# nan
# $2,800
# Quiet and Bright 2br/1ba Richmond Seacliff Neighborhood
# 12/30
# 2br
# richmond / seacliff
# 1
# 67
# https://sfbay.craigslist.org/sfc/apa/7573448011.html
# ['open house dates', 'sunday 2023-01-01', 'monday 2023-01-02', 'tuesday 2023-01-03']
# 396
# $2,500
# #204/ Newly Renovated, Pet Friendly, Gorgeous Space!
# 12/30
# nan
# lower nob hill
# 1
# 68
# https://sfbay.craigslist.org/sfc/apa/7573445560.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# nan
# $2,145
# Modern Units near St. Mary's Square! 2 MONTHS FREE!
# 12/30
# nan
# Nob Hill
# 1
# 69
# https://sfbay.craigslist.org/sfc/apa/7573447504.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'no laundry on site', 'street parking', 'rent period: monthly']
# nan
# $1,725
# 1 MONTH FREE!! Remodeled Kitchen w/ Laundry Onsite
# 12/30
# nan
# Downtown
# 1
# 70
# https://sfbay.craigslist.org/sfc/apa/7573447495.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'street parking', 'rent period: monthly']
# nan
# $2,595
# 1 MONTH FREE! Adjacent to Golden Gate Theatre and Theatre District
# 12/30
# 1br
# Downtown
# 1
# 71
# https://sfbay.craigslist.org/sfc/apa/7573447489.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'street parking', 'rent period: monthly']
# nan
# $1,995
# Upgraded Studio just Three blocks from Union Square! 2 MONTHS FREE!
# 12/30
# nan
# Nob Hill
# 1
# 72
# https://sfbay.craigslist.org/sfc/apa/7573447484.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'no laundry on site', 'street parking', 'rent period: monthly']
# 650
# $2,230
# High-speed Internet Access, Vertical Blinds, Central Air and Heating
# 12/30
# 1br
# alamo square / nopa
# 1
# 73
# https://sfbay.craigslist.org/sfc/apa/7570417967.html
# ['air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'carport', 'rent period: monthly']
# 455
# $2,800
# #5 / Available now! Shared Yard, Laundry In-Unit! Pets okay!
# 12/30
# 1br
# nob hill
# 1
# 74
# https://sfbay.craigslist.org/sfc/apa/7571295693.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# nan
# $1,100
# #104 / Lovely Space, Available now, Co-living at its finest!
# 12/30
# nan
# lower nob hill
# shared
# 75
# https://sfbay.craigslist.org/sfc/apa/7572551655.html
# ['apartment', 'no laundry on site', 'street parking', 'rent period: monthly']
# 788
# $4,100
# #6 / Newly Renovated, Laundry In-unit, Shared Yard!
# 12/30
# 2br
# nob hill
# 2
# 76
# https://sfbay.craigslist.org/sfc/apa/7571292900.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# nan
# $1,200
# #228/ Co-living Space Available now!
# 12/30
# nan
# lower nob hill
# shared
# 77
# https://sfbay.craigslist.org/sfc/apa/7572551995.html
# ['apartment', 'no laundry on site', 'street parking', 'rent period: monthly']
# nan
# $4,800
# $4800 / Miraloma Gem! Gorgeous Single Family Home Available now!
# 12/30
# 3br
# castro / upper market
# 2
# 78
# https://sfbay.craigslist.org/sfc/apa/7572553428.html
# ['house', 'w/d in unit', 'attached garage', 'rent period: monthly']
# nan
# $7,595
# $7595 / Gorgeous Space! Love this Location, Newly Remodeled!
# 12/30
# 5br
# mission district
# 2
# 79
# https://sfbay.craigslist.org/sfc/apa/7572553725.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# 759
# $3,800
# Gorgeous Space, LOVE this location, nice natural light!
# 12/30
# 2br
# mission district
# 1
# 80
# https://sfbay.craigslist.org/sfc/apa/7573445693.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# 700
# $2,100
# Charmin Jr 1 bedroom cottage
# 12/30
# 1br
# russian hill
# 1
# 81
# https://sfbay.craigslist.org/sfc/apa/7571608895.html
# ['cottage/cabin', 'no laundry on site', 'street parking', 'rent period: monthly']
# 1146
# $7,250
# Skybox lounge, Backyard terrace with pizza oven, Public art plaza
# 12/30
# 3br
# SOMA / south beach
# 2
# 82
# https://sfbay.craigslist.org/sfc/apa/7569966004.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 627
# $3,195
# #303/ Brand new space, Pets Welcome, Great Light, In-unit Laundry
# 12/30
# 1br
# lower nob hill
# 1
# 83
# https://sfbay.craigslist.org/sfc/apa/7573443678.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# 800
# $3,000
# Lovely Apartment Full of Light
# 12/30
# 1br
# potrero hill
# 1
# 84
# https://sfbay.craigslist.org/sfc/apa/7573442833.html
# ['apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# 371
# $1,112
# 1 MONTH FREE on Affordable Studio at Ava Nob Hill, Check it out Today!
# 12/30
# nan
# nob hill
# 1
# 85
# https://sfbay.craigslist.org/sfc/apa/7570305678.html
# ['EV charging', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'no smoking', 'detached garage', 'rent period: monthly', 'wheelchair accessible']
# 948
# $4,200
# 2br 2 ba Lease Takeover until 9/23
# 12/30
# 2br
# SOMA / south beach
# 2
# 86
# https://sfbay.craigslist.org/sfc/apa/7566102907.html
# ['application fee details: $40', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'detached garage', 'rent period: monthly', 'wheelchair accessible']
# 1151
# $2,732
# Reserved Covered Parking, Central Air and Heating, Balcony/Deck/Patio
# 12/30
# 2br
# bayview
# 2
# 87
# https://sfbay.craigslist.org/sfc/apa/7573441659.html
# ['air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'carport', 'rent period: monthly', 'wheelchair accessible']
# 813
# $3,500
# Sunny 1 Bedroom/1 Bathroom with View
# 12/30
# 1br
# lower pac hts
# 1
# 88
# https://sfbay.craigslist.org/sfc/apa/7573441572.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# nan
# $3,195
# Large 2 bedroom apartment - Now Available!
# 12/30
# 2br
# ingleside / SFSU / CCSF
# 1
# 89
# https://sfbay.craigslist.org/sfc/apa/7573441209.html
# ['apartment', 'laundry in bldg', 'detached garage', 'rent period: monthly']
# 587
# $2,942
# 4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!
# 12/30
# 1br
# lower nob hill
# 1
# 90
# https://sfbay.craigslist.org/sfc/apa/7573436609.html
# ['open house dates', 'saturday 2022-12-31', 'monday 2023-01-02', 'tuesday 2023-01-03']
# 670
# $3,751
# 4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!
# 12/30
# 1br
# lower nob hill
# 1
# 91
# https://sfbay.craigslist.org/sfc/apa/7573437365.html
# ['open house dates', 'saturday 2022-12-31', 'monday 2023-01-02', 'tuesday 2023-01-03']
# 700
# $3,950
# The Holidays are Here! Treat Yourself to a new 2x1 Apartment!
# 12/30
# 2br
# pacific heights
# 1
# 92
# https://sfbay.craigslist.org/sfc/apa/7573439571.html
# ['cats are OK - purrr', 'apartment', 'laundry on site', 'no smoking', 'street parking', 'rent period: monthly']
# 472
# $2,525
# 4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!
# 12/30
# nan
# lower nob hill
# 1
# 93
# https://sfbay.craigslist.org/sfc/apa/7573434672.html
# ['open house dates', 'saturday 2022-12-31', 'monday 2023-01-02', 'tuesday 2023-01-03']
# 280
# $1,650
# Amazing studio in sunset district
# 12/30
# 1br
# sunset / parkside
# 1
# 94
# https://sfbay.craigslist.org/sfc/apa/7573438947.html
# ['apartment', 'laundry in bldg', 'no smoking', 'street parking', 'rent period: monthly']
# 969
# $3,979
# 4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!
# 12/30
# 1br
# lower nob hill
# 1
# 95
# https://sfbay.craigslist.org/sfc/apa/7573438581.html
# ['open house dates', 'saturday 2022-12-31', 'monday 2023-01-02', 'tuesday 2023-01-03']
# 1396
# $5,650
# L Haight | 3Bd 2Ba Flat | Balcony | Yard | Garage | Laundry | ReLISTO
# 12/30
# 3br
# lower haight
# 2
# 96
# https://sfbay.craigslist.org/sfc/apa/7573437827.html
# ['saturday 2022-12-31']
# 300
# $2,200
# Video entry system, Architectural distinction, Gas range
# 12/30
# nan
# lower nob hill
# 1
# 97
# https://sfbay.craigslist.org/sfc/apa/7566249085.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $3,095
# VINTAGE MEETS MODERN IN NOB HILL 1BD 1BA WITH W/D IN UNIT
# 12/30
# 1br
# Nob Hill
# 1
# 98
# https://sfbay.craigslist.org/sfc/apa/7572755884.html
# ['application fee details: $35 one-time application processing fee when you apply', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $4,695
# BEAUTIFUL PACIFIC HEIGHTS 2BD 1BA WITH LARGE CLOSETS
# 12/30
# 2br
# Pacific Heights
# 1
# 99
# https://sfbay.craigslist.org/sfc/apa/7572752896.html
# ['application fee details: $35 one-time application processing fee when you apply', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $3,795
# VINTAGE CLASSIC LOWER NOB HILL 2BD 1BA WITH W/D IN UNIT
# 12/30
# 2br
# Lower Nob Hill
# 1
# 100
# https://sfbay.craigslist.org/sfc/apa/7572748585.html
# ['application fee details: $35 one-time application processing fee when you apply', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $2,895
# UPSCALE LIVING IN LOWER NOB HILL 1BD 1BA WITH W/D IN UNIT
# 12/30
# 1br
# Lower Nob Hill
# 1
# 101
# https://sfbay.craigslist.org/sfc/apa/7572748402.html
# ['application fee details: $35 one-time application processing fee when you apply', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $3,995
# STUNNING UPDATES IN RUSSIAN HILL 2B 1BA GEM~ W/D IN UNIT
# 12/30
# 2br
# Russian Hill
# 1
# 102
# https://sfbay.craigslist.org/sfc/apa/7572748144.html
# ['application fee details: $35 one-time application fee when you apply', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $4,395
# EXCEPTIONAL NORTH BEACH 1BD 1BA WITH VIEWS AND W/D IN UNIT
# 12/30
# 2br
# North Beach
# 2
# 103
# https://sfbay.craigslist.org/sfc/apa/7572747946.html
# ['application fee details: $35 one-time application processing fee when you apply', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $5,195
# PAC HEIGHTS MID-CENTURY MODERN 3BD 2BA WITH W/D IN UNIT
# 12/30
# 3br
# Pacific Heights
# 2
# 104
# https://sfbay.craigslist.org/sfc/apa/7572747740.html
# ['application fee details: $35 one-time application processing fee when you apply', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'no parking', 'rent period: monthly']
# nan
# $3,300
# FULLY FURNISHED, 3month min, Walk to waterfront gym 24hr drmn, w/dryer
# 12/30
# 1br
# SOMA / south beach
# 1
# 105
# https://sfbay.craigslist.org/sfc/apa/7564788676.html
# ['furnished', 'condo', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly']
# 582
# $3,351
# 4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!
# 12/30
# 1br
# lower nob hill
# 1
# 106
# https://sfbay.craigslist.org/sfc/apa/7573436166.html
# ['open house dates', 'saturday 2022-12-31', 'monday 2023-01-02', 'tuesday 2023-01-03']
# 472
# $2,354
# 4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!
# 12/30
# nan
# lower nob hill
# 1
# 107
# https://sfbay.craigslist.org/sfc/apa/7573435757.html
# ['open house dates', 'saturday 2022-12-31', 'monday 2023-01-02', 'tuesday 2023-01-03']
# 792
# $4,301
# Public art plaza, Bike Storage & Repair
# 12/30
# 2br
# SOMA / south beach
# 1
# 108
# https://sfbay.craigslist.org/sfc/apa/7566146800.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 1196
# $5,927
# Pre-wired for telephone, data and TV, Bike share, Roller shades
# 12/30
# 2br
# SOMA / south beach
# 2
# 109
# https://sfbay.craigslist.org/sfc/apa/7573435378.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'valet parking', 'rent period: monthly', 'wheelchair accessible']
# 590
# $2,798
# Immediate Move in by 12/31 Get 1 month free + reduced deposit of 250
# 12/30
# 1br
# lower nob hill
# 1
# 110
# https://sfbay.craigslist.org/sfc/apa/7573434779.html
# ['apartment', 'laundry on site', 'carport', 'rent period: monthly']
# 1023
# $3,750
# Spacious newly renovated 2BR/1BA Pet Friendly + Garage Parking
# 12/30
# 2br
# inner richmond
# 1
# 111
# https://sfbay.craigslist.org/sfc/apa/7573430601.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry in bldg', 'no smoking', 'attached garage', 'rent period: monthly']
# 1042
# $3,713
# After Specials: Co-working library, Stainless steel appliances
# 12/30
# 2br
# SOMA / south beach
# 2
# 112
# https://sfbay.craigslist.org/sfc/apa/7573434386.html
# ['EV charging', 'air conditioning', 'cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
# 860
# $2,500
# $2500 two bedrooms, 1400, 47 Avenue, Apt.3 , SF CA 94122
# 12/30
# 2br
# sunset / parkside
# 1
# 113
# https://sfbay.craigslist.org/sfc/apa/7573433281.html
# ['open house dates', 'saturday 2022-12-31', 'sunday 2023-01-01', 'saturday 2023-01-07']
# 860
# $2,500
# $2500 two bedrooms, 1400, 47 Avenue, Apt.3 , SF CA 94122
# 12/30
# 2br
# sunset / parkside
# 1
# 114
# https://sfbay.craigslist.org/sfc/apa/7573433910.html
# ['open house dates', 'saturday 2022-12-31', 'sunday 2023-01-01', 'saturday 2023-01-07']
# 607
# $4,200
# Luxury - 1 bedroom - Parking Available - Storage Cage -
# 12/30
# 1br
# financial district
# 1
# 115
# https://sfbay.craigslist.org/sfc/apa/7569187457.html
# ['air conditioning', 'apartment', 'w/d in unit', 'no smoking', 'attached garage', 'rent period: monthly']
# 860
# $2,500
# $2500 two bedrooms, 1400, 47 Avenue, Apt.3 , SF CA 94122
# 12/30
# 2br
# sunset / parkside
# 1
# 116
# https://sfbay.craigslist.org/sfc/apa/7572730469.html
# ['open house dates', 'saturday 2022-12-31', 'sunday 2023-01-01', 'saturday 2023-01-07']
# nan
# $2,200
# Free Blazing Fast Wifi Sunset 2 Bed/1 Bath Apt With Gorgeous Backyard
# 12/30
# 2br
# sunset / parkside
# 1
# 117
# https://sfbay.craigslist.org/sfc/apa/7573429201.html
# ['apartment', 'laundry on site', 'no smoking', 'street parking', 'rent period: monthly']
# 860
# $2,850
# Two bedrooms, 155 at 20 Ave. Apt 2, SF, CA
# 12/30
# 2br
# richmond / seacliff
# 1
# 118
# https://sfbay.craigslist.org/sfc/apa/7573431949.html
# ['open house dates', 'saturday 2022-12-31', 'sunday 2023-01-01', 'saturday 2023-01-07']
# 940
# $3,320
# Sunset District apartment walk to UCSF, GG Park. Mins to SF FiDi
# 12/30
# 2br
# inner sunset / UCSF
# 1
# 119
# https://sfbay.craigslist.org/sfc/apa/7573432099.html
# ['apartment', 'laundry in bldg', 'attached garage', 'rent period: monthly']

# %%
datatoget
# Out:
# [{'date': '12/31',
#   'title': '2 bdr. with awesome City view',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573487609.html',
#   'price': '$3,985',
#   'bedroom': '2br',
#   'sqft': '920',
#   'neighborhood': 'cole valley / ashbury hts',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'Skybox lounge, Valet parking, Reception lobby bar and café',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7565465402.html',
#   'price': '$3,961',
#   'bedroom': '1br',
#   'sqft': '745',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '1',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/31',
#   'title': 'Fourth-floor studio in Theater District',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573485201.html',
#   'price': '$1,550',
#   'bedroom': nan,
#   'sqft': '300',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'Skybox lounge, Public art plaza, Valet parking',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7567879622.html',
#   'price': '$7,435',
#   'bedroom': '3br',
#   'sqft': '1146',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/31',
#   'title': 'Beautiful Landscaping, Microwave, Covered Parking',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571564203.html',
#   'price': '$2,785',
#   'bedroom': '2br',
#   'sqft': '1000',
#   'neighborhood': 'alamo square / nopa',
#   'bathroom': '1.5',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'TOP FLOOR Remodeled 2-bedroom unit with Parking',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7564305873.html',
#   'price': '$2,675',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'inner richmond',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'TOP FLOOR Remodeled 2-bedroom unit with Parking',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7564301680.html',
#   'price': '$2,675',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'richmond / seacliff',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'Public art plaza, Skybox lounge, EV & scooter charging stations',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7564902244.html',
#   'price': '$7,250',
#   'bedroom': '3br',
#   'sqft': '1146',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/31',
#   'title': 'Excellent location in one of the best blocks in Central Sunset',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7563685539.html',
#   'price': '$2,800',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-10',
#    'sunday 2022-12-11',
#    'saturday 2022-12-17']},
#  {'date': '12/31',
#   'title': 'Excellent location in one of the best blocks in Central Sunset',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7566474440.html',
#   'price': '$2,800',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-10',
#    'sunday 2022-12-11',
#    'saturday 2022-12-17']},
#  {'date': '12/31',
#   'title': 'Studio Apartment (Recently Remodeled)',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7563680936.html',
#   'price': '$2,200',
#   'bedroom': nan,
#   'sqft': '400',
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['duplex',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': '1Month free+ reduced deposit of  $250 When you Move in by 12/31/22',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571160411.html',
#   'price': '$2,688',
#   'bedroom': '1br',
#   'sqft': '590',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'Studio Apartment (Recently Remodeled)',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7563682428.html',
#   'price': '$2,200',
#   'bedroom': nan,
#   'sqft': '400',
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['duplex',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'Bike Storage & Repair, Public art plaza, Valet parking',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7568329878.html',
#   'price': '$4,995',
#   'bedroom': '2br',
#   'sqft': '1130',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/31',
#   'title': 'Awesome value! GREAT Location!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571565326.html',
#   'price': '$2,160',
#   'bedroom': '1br',
#   'sqft': '650',
#   'neighborhood': 'alamo square / nopa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'Bike Storage & Repair, Public art plaza, Reception lobby bar and café',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571909986.html',
#   'price': '$7,250',
#   'bedroom': '3br',
#   'sqft': '1146',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/31',
#   'title': 'Top floor - very bright! * Just fully remodeled!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573472424.html',
#   'price': '$1,750',
#   'bedroom': nan,
#   'sqft': '450',
#   'neighborhood': 'city of san francisco',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'condo',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': '两房 Mission&Geneva/Balboa BART 租',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570533113.html',
#   'price': '$2,000',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'excelsior / outer mission',
#   'bathroom': '1',
#   'amenities': ['in-law',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': '3br - 3 Bedrooms & 3 Bath Townhouse Condo',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573473452.html',
#   'price': '$5,250',
#   'bedroom': '3br',
#   'sqft': '1700',
#   'neighborhood': 'richmond / seacliff',
#   'bathroom': '3',
#   'amenities': ['condo',
#    'w/d in unit',
#    'no smoking',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'Get 1Month free+ Reduced Deposit  When you Move in By 12/31/22',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571127897.html',
#   'price': '$2,019',
#   'bedroom': nan,
#   'sqft': '441',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': '5 bedrooms, renovated, parking, Nice , Near hospital',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573472917.html',
#   'price': '$5,295',
#   'bedroom': '5br',
#   'sqft': nan,
#   'neighborhood': 'potrero hill',
#   'bathroom': '3',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'Brand New Remodeled Unit with Vintage Edwardian charm',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573472661.html',
#   'price': '$3,350',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'noe valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/31',
#   'title': 'EV & scooter charging stations, Public art plaza',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7566088593.html',
#   'price': '$7,435',
#   'bedroom': '3br',
#   'sqft': '1146',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'Newly renovated unit (2021) within steps of panoramic views of San Fra',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573469813.html',
#   'price': '$2,150',
#   'bedroom': '1br',
#   'sqft': '650',
#   'neighborhood': 'city of san francisco',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'condo',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Sunny Corner Unit',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570157113.html',
#   'price': '$2,900',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'GREAT NOE 3BR+2BA.HOUSE! Large,Sunny LandscYard,InUnitWD,Deck,Parking~',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7569595913.html',
#   'price': '$4,495',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'noe valley',
#   'bathroom': '2',
#   'amenities': ['application fee details: $40 - for each applicant.',
#    'house',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Balcony or Patio, Cable Ready, Shimmering Swimming Pool',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570416555.html',
#   'price': '$2,080',
#   'bedroom': '1br',
#   'sqft': '535',
#   'neighborhood': 'alamo square / nopa',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '**~**Have A Nice one bedroom apartment in SF Bay Area**~**.',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573463655.html',
#   'price': '$800',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'one bed and one den for rent',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573464818.html',
#   'price': '$2,500',
#   'bedroom': '2br',
#   'sqft': '495',
#   'neighborhood': 'San Francisco',
#   'bathroom': '1',
#   'amenities': ['house',
#    'laundry on site',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': "couple's favorite !one bed with living room, big kitchen and  bath for rent",
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573464771.html',
#   'price': '$2,500',
#   'bedroom': '1br',
#   'sqft': '495',
#   'neighborhood': 'San Francisco',
#   'bathroom': '1',
#   'amenities': ['house',
#    'laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Lovely Outer Sunset Studio by Ocean Beach and shops',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572044866.html',
#   'price': '$1,495',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Outer Sunset',
#   'bathroom': '1',
#   'amenities': ['in-law',
#    'laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'TOP Victorian Flat-PANO Vus! Sunny,HdWd,Yard,Patio,Deck,Storage',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7566311753.html',
#   'price': '$4,395',
#   'bedroom': '2br',
#   'sqft': '1200',
#   'neighborhood': 'noe valley',
#   'bathroom': '1',
#   'amenities': ['application fee details: $40-Application/Job Verification',
#    'flat',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '*BEST NOE LOCATION! SunnyYard/Private Patio,In-unitWD,HdWdFlrs!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7569595702.html',
#   'price': '$3,475',
#   'bedroom': '2br',
#   'sqft': '1000',
#   'neighborhood': 'noe valley',
#   'bathroom': '1',
#   'amenities': ['application fee details: $40 each for credit check & job verification.',
#    'duplex',
#    'w/d in unit',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'GREAT NOE 3BR+2BA.HOUSE! Large,Sunny LandscYard,InUnitWD,Deck,Parking~',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7569595517.html',
#   'price': '$4,495',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'noe valley',
#   'bathroom': '2',
#   'amenities': ['application fee details: $40 - for each applicant.',
#    'house',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'One Bedroom Apartment (Sacramento & Leavenworth)',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7563897630.html',
#   'price': '$1,850',
#   'bedroom': '1br',
#   'sqft': '450',
#   'neighborhood': 'nob hill',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'EPIC REA-HALF MONTH FREE RENT-Bright/Beautiful 1BD/1BA w/PKG & Wash/Dr',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573464462.html',
#   'price': '$2,495',
#   'bedroom': '1br',
#   'sqft': '442',
#   'neighborhood': 'visitacion valley',
#   'bathroom': '1',
#   'amenities': ['application fee details: $45 Tenant Screening and application',
#    'duplex',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'EPIC REA - Beautiful 3BR/1BA lower flat unit  with a walk score 98/100',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573463862.html',
#   'price': '$3,100',
#   'bedroom': '3br',
#   'sqft': '900',
#   'neighborhood': 'mission district',
#   'bathroom': '1',
#   'amenities': ['application fee details: $45 Tenant screening and application',
#    'duplex',
#    'w/d in unit',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Reduced, prime Dogpatch location, Live/work Loft available',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7567032856.html',
#   'price': '$3,375',
#   'bedroom': '1br',
#   'sqft': '1325',
#   'neighborhood': 'potrero hill',
#   'bathroom': '1',
#   'amenities': ['application fee details: $30.00 application fee per applicant',
#    'cats are OK - purrr',
#    'loft',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'EPIC REA_AZARI PM-UPDATED KITCHEN ,FLOOR ,BATHROOMS OF THIS COSY HOUSE',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571192781.html',
#   'price': '$4,250',
#   'bedroom': '3br',
#   'sqft': '1200',
#   'neighborhood': 'excelsior / outer mission',
#   'bathroom': '2',
#   'amenities': ['application fee details: $45 - Tenant screening and application',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'EpicREA-AzariPM-Fabulous View 1 BR + Den or Dining/1 BA -Arterra w/Pkg',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570699519.html',
#   'price': '$3,850',
#   'bedroom': '1br',
#   'sqft': '856',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '1',
#   'amenities': ['application fee details: $45 - tenant screening & processing',
#    'condo',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'EpicREA - Fabulous Modern Large Studio/ with 1 bath with Views',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570686750.html',
#   'price': '$2,300',
#   'bedroom': nan,
#   'sqft': '500',
#   'neighborhood': 'bayview',
#   'bathroom': '1',
#   'amenities': ['application fee details: $45 Tenant screening and application',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Epic REA -Live On Top of Nob Hill w/Views of Huntington Park',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571441919.html',
#   'price': '$5,995',
#   'bedroom': '2br',
#   'sqft': '1540',
#   'neighborhood': 'nob hill',
#   'bathroom': '2',
#   'amenities': ['application fee details: $45 Tenant screening and processing',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'EV & scooter charging stations, Attended arrival desk, Skybox lounge',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572239877.html',
#   'price': '$7,435',
#   'bedroom': '3br',
#   'sqft': '1146',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'EXECUTIVE HOME PARKING YARD LAUNDRY CHARGER! IDEAL LOCATION!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573460723.html',
#   'price': '$8,990',
#   'bedroom': '4br',
#   'sqft': '2600',
#   'neighborhood': 'west portal / forest hill',
#   'bathroom': '3',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Spacious 1 bed 1 bath in the Marina',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572467273.html',
#   'price': '$2,795',
#   'bedroom': '1br',
#   'sqft': '750',
#   'neighborhood': 'marina / cow hollow',
#   'bathroom': '1',
#   'amenities': ['application fee details: $40 application fee to check credit and background',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Cozy clean studio in the Marina',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572744140.html',
#   'price': '$1,850',
#   'bedroom': '1br',
#   'sqft': '400',
#   'neighborhood': 'marina / cow hollow',
#   'bathroom': '1',
#   'amenities': ['application fee details: $40 application fee to check credit and background',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'AMAZING! 2BR/1.5B Live/Work Loft (Parking Included!)',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7565579588.html',
#   'price': '$3,900',
#   'bedroom': '2br',
#   'sqft': '1254',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '1.5',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'loft',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'BEAUTIFUL 2BED HOME PARKING LAUNDRY AVAILABLE! IDEAL SF LOCATION!!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573458778.html',
#   'price': '$3,980',
#   'bedroom': '2br',
#   'sqft': '1000',
#   'neighborhood': 'inner richmond',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Regina Towers Apartment for Rent',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7565442839.html',
#   'price': '$2,300',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Get 1month free + reduced deposit of  $250 W/ Private patio',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572783959.html',
#   'price': '$2,720',
#   'bedroom': '1br',
#   'sqft': '556',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Rare 2 bed/1 bath with parking, yard, w/d and the best access!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573458101.html',
#   'price': '$3,600',
#   'bedroom': '2br',
#   'sqft': '850',
#   'neighborhood': 'San Francisco',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'furnished',
#    'house',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Beautiful spacious two bedrooms top floor',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573461268.html',
#   'price': '$3,600',
#   'bedroom': '2br',
#   'sqft': '1100',
#   'neighborhood': 'richmond / seacliff',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'house',
#    'laundry on site',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Beautiful spacious two bedrooms top floor',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573461123.html',
#   'price': '$3,600',
#   'bedroom': '2br',
#   'sqft': '1100',
#   'neighborhood': 'richmond / seacliff',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'house',
#    'laundry on site',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Beautiful spacious two bedrooms top floor',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570186732.html',
#   'price': '$3,600',
#   'bedroom': '2br',
#   'sqft': '1100',
#   'neighborhood': 'richmond / seacliff',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'house',
#    'laundry on site',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '2bd/2ba Historic North Beach Malthouse- Available Jan',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573459034.html',
#   'price': '$5,200',
#   'bedroom': '2br',
#   'sqft': '1200',
#   'neighborhood': 'north beach / telegraph hill',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Spacious 2 bedroom, 1 bathroom condo',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573451903.html',
#   'price': '$870',
#   'bedroom': '2br',
#   'sqft': '1030',
#   'neighborhood': 'SF bay area',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Large spacious 2/3 bedroom apartment',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570548800.html',
#   'price': '$3,800',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'inner richmond',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Russian Hill Apt. in Green/Hyde Sts. Neighborhood',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7567022272.html',
#   'price': '$3,100',
#   'bedroom': '2br',
#   'sqft': '800',
#   'neighborhood': 'russian hill',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'two bedroom / commercial space',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570546887.html',
#   'price': '$3,000',
#   'bedroom': '2br',
#   'sqft': '800',
#   'neighborhood': 'inner richmond',
#   'bathroom': '1.5',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Backyard terrace with pizza oven, Bike Storage & Repair',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7565904358.html',
#   'price': '$3,436',
#   'bedroom': '1br',
#   'sqft': '596',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '1',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'Spacious Full House in Excelsior with Parking and Abundant Storage!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573453333.html',
#   'price': '$3,800',
#   'bedroom': '3br',
#   'sqft': '955',
#   'neighborhood': 'excelsior / outer mission',
#   'bathroom': '1',
#   'amenities': ['application fee details: $50',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'house',
#    'laundry on site',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Spacious and Bright 3BR Flat with Parking Available and Backyard',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573449363.html',
#   'price': '$3,950',
#   'bedroom': '3br',
#   'sqft': '1300',
#   'neighborhood': 'excelsior / outer mission',
#   'bathroom': '2',
#   'amenities': ['application fee details: $50',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'SOMA Luxury Furnished Executive Retreat',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573449709.html',
#   'price': '$9,500',
#   'bedroom': '1br',
#   'sqft': '2300',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2.5',
#   'amenities': ['application fee details: $50 per adult',
#    'broker fee details: Lease Fee $350',
#    'furnished',
#    'condo',
#    'w/d in unit',
#    'listed by: Home 2 San Francisco',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Penthouse,Top of the world, Private view deck, Fresh air, Unique+Rare',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7565099786.html',
#   'price': '$4,295',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'inner richmond',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Bright and Spacious 2 BD 1 BA Unit for Rent! Available Now!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7567326532.html',
#   'price': '$3,800',
#   'bedroom': '2br',
#   'sqft': '1200',
#   'neighborhood': 'USF / panhandle',
#   'bathroom': '1',
#   'amenities': ['duplex',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Leasing Now, Yoga Studio with Spin Bikes, Walk In Closets',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573427669.html',
#   'price': '$3,809',
#   'bedroom': '1br',
#   'sqft': '805',
#   'neighborhood': 'hayes valley',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Available 2-1, quiet pet-friendly apt. on beautiful Cole Valley street',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573448698.html',
#   'price': '$2,600',
#   'bedroom': '1br',
#   'sqft': '400',
#   'neighborhood': 'cole valley / ashbury hts',
#   'bathroom': '1',
#   'amenities': ['application fee details: $40 credit check',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Quiet and Bright 2br/1ba Richmond Seacliff Neighborhood',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573448011.html',
#   'price': '$2,800',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'richmond / seacliff',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'sunday 2023-01-01',
#    'monday 2023-01-02',
#    'tuesday 2023-01-03']},
#  {'date': '12/30',
#   'title': '#204/ Newly Renovated, Pet Friendly, Gorgeous Space!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573445560.html',
#   'price': '$2,500',
#   'bedroom': nan,
#   'sqft': '396',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': "Modern Units near St. Mary's Square! 2 MONTHS FREE!",
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573447504.html',
#   'price': '$2,145',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Nob Hill',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'no laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '1 MONTH FREE!! Remodeled Kitchen w/ Laundry Onsite',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573447495.html',
#   'price': '$1,725',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Downtown',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '1 MONTH FREE! Adjacent to Golden Gate Theatre and Theatre District',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573447489.html',
#   'price': '$2,595',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Downtown',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Upgraded Studio just Three blocks from Union Square! 2 MONTHS FREE!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573447484.html',
#   'price': '$1,995',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Nob Hill',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'no laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'High-speed Internet Access, Vertical Blinds, Central Air and Heating',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570417967.html',
#   'price': '$2,230',
#   'bedroom': '1br',
#   'sqft': '650',
#   'neighborhood': 'alamo square / nopa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '#5 / Available now! Shared Yard, Laundry In-Unit! Pets okay!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571295693.html',
#   'price': '$2,800',
#   'bedroom': '1br',
#   'sqft': '455',
#   'neighborhood': 'nob hill',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '#104 / Lovely Space, Available now, Co-living at its finest!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572551655.html',
#   'price': '$1,100',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'lower nob hill',
#   'bathroom': 'shared',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '#6 / Newly Renovated, Laundry In-unit, Shared Yard!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571292900.html',
#   'price': '$4,100',
#   'bedroom': '2br',
#   'sqft': '788',
#   'neighborhood': 'nob hill',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '#228/ Co-living Space Available now!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572551995.html',
#   'price': '$1,200',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'lower nob hill',
#   'bathroom': 'shared',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '$4800 / Miraloma Gem! Gorgeous Single Family Home Available now!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572553428.html',
#   'price': '$4,800',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'castro / upper market',
#   'bathroom': '2',
#   'amenities': ['house',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '$7595 / Gorgeous Space! Love this Location, Newly Remodeled!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572553725.html',
#   'price': '$7,595',
#   'bedroom': '5br',
#   'sqft': nan,
#   'neighborhood': 'mission district',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Gorgeous Space, LOVE this location, nice natural light!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573445693.html',
#   'price': '$3,800',
#   'bedroom': '2br',
#   'sqft': '759',
#   'neighborhood': 'mission district',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Charmin Jr 1 bedroom cottage',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7571608895.html',
#   'price': '$2,100',
#   'bedroom': '1br',
#   'sqft': '700',
#   'neighborhood': 'russian hill',
#   'bathroom': '1',
#   'amenities': ['cottage/cabin',
#    'no laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Skybox lounge, Backyard terrace with pizza oven, Public art plaza',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7569966004.html',
#   'price': '$7,250',
#   'bedroom': '3br',
#   'sqft': '1146',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': '#303/ Brand new space, Pets Welcome, Great Light, In-unit Laundry',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573443678.html',
#   'price': '$3,195',
#   'bedroom': '1br',
#   'sqft': '627',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Lovely Apartment Full of Light',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573442833.html',
#   'price': '$3,000',
#   'bedroom': '1br',
#   'sqft': '800',
#   'neighborhood': 'potrero hill',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '1 MONTH FREE on Affordable Studio at Ava Nob Hill, Check it out Today!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7570305678.html',
#   'price': '$1,112',
#   'bedroom': nan,
#   'sqft': '371',
#   'neighborhood': 'nob hill',
#   'bathroom': '1',
#   'amenities': ['EV charging',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'detached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': '2br 2 ba Lease Takeover until 9/23',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7566102907.html',
#   'price': '$4,200',
#   'bedroom': '2br',
#   'sqft': '948',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['application fee details: $40',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'detached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'Reserved Covered Parking, Central Air and Heating, Balcony/Deck/Patio',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573441659.html',
#   'price': '$2,732',
#   'bedroom': '2br',
#   'sqft': '1151',
#   'neighborhood': 'bayview',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'Sunny 1 Bedroom/1 Bathroom with View',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573441572.html',
#   'price': '$3,500',
#   'bedroom': '1br',
#   'sqft': '813',
#   'neighborhood': 'lower pac hts',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'Large 2 bedroom apartment - Now Available!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573441209.html',
#   'price': '$3,195',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'ingleside / SFSU / CCSF',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573436609.html',
#   'price': '$2,942',
#   'bedroom': '1br',
#   'sqft': '587',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'monday 2023-01-02',
#    'tuesday 2023-01-03']},
#  {'date': '12/30',
#   'title': '4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573437365.html',
#   'price': '$3,751',
#   'bedroom': '1br',
#   'sqft': '670',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'monday 2023-01-02',
#    'tuesday 2023-01-03']},
#  {'date': '12/30',
#   'title': 'The Holidays are Here! Treat Yourself to a new 2x1 Apartment!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573439571.html',
#   'price': '$3,950',
#   'bedroom': '2br',
#   'sqft': '700',
#   'neighborhood': 'pacific heights',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573434672.html',
#   'price': '$2,525',
#   'bedroom': nan,
#   'sqft': '472',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'monday 2023-01-02',
#    'tuesday 2023-01-03']},
#  {'date': '12/30',
#   'title': 'Amazing studio in sunset district',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573438947.html',
#   'price': '$1,650',
#   'bedroom': '1br',
#   'sqft': '280',
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573438581.html',
#   'price': '$3,979',
#   'bedroom': '1br',
#   'sqft': '969',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'monday 2023-01-02',
#    'tuesday 2023-01-03']},
#  {'date': '12/30',
#   'title': 'L Haight | 3Bd 2Ba Flat | Balcony | Yard | Garage | Laundry | ReLISTO',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573437827.html',
#   'price': '$5,650',
#   'bedroom': '3br',
#   'sqft': '1396',
#   'neighborhood': 'lower haight',
#   'bathroom': '2',
#   'amenities': ['saturday 2022-12-31']},
#  {'date': '12/30',
#   'title': 'Video entry system, Architectural distinction, Gas range',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7566249085.html',
#   'price': '$2,200',
#   'bedroom': nan,
#   'sqft': '300',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'VINTAGE MEETS MODERN IN NOB HILL 1BD 1BA WITH W/D IN UNIT',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572755884.html',
#   'price': '$3,095',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Nob Hill',
#   'bathroom': '1',
#   'amenities': ['application fee details: $35 one-time application processing fee when you apply',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'BEAUTIFUL PACIFIC HEIGHTS 2BD 1BA WITH LARGE CLOSETS',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572752896.html',
#   'price': '$4,695',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Pacific Heights',
#   'bathroom': '1',
#   'amenities': ['application fee details: $35 one-time application processing fee when you apply',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'VINTAGE CLASSIC LOWER NOB HILL 2BD 1BA WITH W/D IN UNIT',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572748585.html',
#   'price': '$3,795',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Lower Nob Hill',
#   'bathroom': '1',
#   'amenities': ['application fee details: $35 one-time application processing fee when you apply',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'UPSCALE LIVING IN LOWER NOB HILL 1BD 1BA WITH W/D IN UNIT',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572748402.html',
#   'price': '$2,895',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Lower Nob Hill',
#   'bathroom': '1',
#   'amenities': ['application fee details: $35 one-time application processing fee when you apply',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'STUNNING UPDATES IN RUSSIAN HILL 2B 1BA GEM~ W/D IN UNIT',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572748144.html',
#   'price': '$3,995',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Russian Hill',
#   'bathroom': '1',
#   'amenities': ['application fee details: $35 one-time application fee when you apply',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'EXCEPTIONAL NORTH BEACH 1BD 1BA WITH VIEWS AND W/D IN UNIT',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572747946.html',
#   'price': '$4,395',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'North Beach',
#   'bathroom': '2',
#   'amenities': ['application fee details: $35 one-time application processing fee when you apply',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'PAC HEIGHTS MID-CENTURY MODERN 3BD 2BA WITH W/D IN UNIT',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572747740.html',
#   'price': '$5,195',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Pacific Heights',
#   'bathroom': '2',
#   'amenities': ['application fee details: $35 one-time application processing fee when you apply',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'FULLY FURNISHED, 3month min, Walk to waterfront gym 24hr drmn, w/dryer',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7564788676.html',
#   'price': '$3,300',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '1',
#   'amenities': ['furnished',
#    'condo',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573436166.html',
#   'price': '$3,351',
#   'bedroom': '1br',
#   'sqft': '582',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'monday 2023-01-02',
#    'tuesday 2023-01-03']},
#  {'date': '12/30',
#   'title': '4-8 Weeks FREE Limited-time Promo. Appliances Incl., City View&More!',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573435757.html',
#   'price': '$2,354',
#   'bedroom': nan,
#   'sqft': '472',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'monday 2023-01-02',
#    'tuesday 2023-01-03']},
#  {'date': '12/30',
#   'title': 'Public art plaza, Bike Storage & Repair',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7566146800.html',
#   'price': '$4,301',
#   'bedroom': '2br',
#   'sqft': '792',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '1',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'Pre-wired for telephone, data and TV, Bike share, Roller shades',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573435378.html',
#   'price': '$5,927',
#   'bedroom': '2br',
#   'sqft': '1196',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'valet parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': 'Immediate Move in by 12/31 Get 1 month free + reduced deposit of 250',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573434779.html',
#   'price': '$2,798',
#   'bedroom': '1br',
#   'sqft': '590',
#   'neighborhood': 'lower nob hill',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'carport',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Spacious newly renovated 2BR/1BA Pet Friendly + Garage Parking',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573430601.html',
#   'price': '$3,750',
#   'bedroom': '2br',
#   'sqft': '1023',
#   'neighborhood': 'inner richmond',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'After Specials: Co-working library, Stainless steel appliances',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573434386.html',
#   'price': '$3,713',
#   'bedroom': '2br',
#   'sqft': '1042',
#   'neighborhood': 'SOMA / south beach',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '12/30',
#   'title': '$2500 two bedrooms, 1400, 47 Avenue, Apt.3 , SF CA 94122',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573433281.html',
#   'price': '$2,500',
#   'bedroom': '2br',
#   'sqft': '860',
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'sunday 2023-01-01',
#    'saturday 2023-01-07']},
#  {'date': '12/30',
#   'title': '$2500 two bedrooms, 1400, 47 Avenue, Apt.3 , SF CA 94122',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573433910.html',
#   'price': '$2,500',
#   'bedroom': '2br',
#   'sqft': '860',
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'sunday 2023-01-01',
#    'saturday 2023-01-07']},
#  {'date': '12/30',
#   'title': 'Luxury - 1 bedroom - Parking Available - Storage Cage -',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7569187457.html',
#   'price': '$4,200',
#   'bedroom': '1br',
#   'sqft': '607',
#   'neighborhood': 'financial district',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': '$2500 two bedrooms, 1400, 47 Avenue, Apt.3 , SF CA 94122',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7572730469.html',
#   'price': '$2,500',
#   'bedroom': '2br',
#   'sqft': '860',
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'sunday 2023-01-01',
#    'saturday 2023-01-07']},
#  {'date': '12/30',
#   'title': 'Free Blazing Fast Wifi Sunset 2 Bed/1 Bath Apt With Gorgeous Backyard',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573429201.html',
#   'price': '$2,200',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'sunset / parkside',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '12/30',
#   'title': 'Two bedrooms, 155 at 20 Ave. Apt 2, SF, CA',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573431949.html',
#   'price': '$2,850',
#   'bedroom': '2br',
#   'sqft': '860',
#   'neighborhood': 'richmond / seacliff',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'saturday 2022-12-31',
#    'sunday 2023-01-01',
#    'saturday 2023-01-07']},
#  {'date': '12/30',
#   'title': 'Sunset District apartment walk to UCSF, GG Park. Mins to SF FiDi',
#   'link': 'https://sfbay.craigslist.org/sfc/apa/7573432099.html',
#   'price': '$3,320',
#   'bedroom': '2br',
#   'sqft': '940',
#   'neighborhood': 'inner sunset / UCSF',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'attached garage',
#    'rent period: monthly']}]

# %%
# creating DataFrame
df = pd.DataFrame(datatoget)
df
# Out:
#       date                                              title  \
# 0    12/31                      2 bdr. with awesome City view
# 1    12/31  Skybox lounge, Valet parking, Reception lobby ...
# 2    12/31            Fourth-floor studio in Theater District
# 3    12/31     Skybox lounge, Public art plaza, Valet parking
# 4    12/31  Beautiful Landscaping, Microwave, Covered Parking
# ..     ...                                                ...
# 115  12/30  Luxury - 1 bedroom - Parking Available - Stora...
# 116  12/30  $2500 two bedrooms, 1400, 47 Avenue, Apt.3 , S...
# 117  12/30  Free Blazing Fast Wifi Sunset 2 Bed/1 Bath Apt...
# 118  12/30         Two bedrooms, 155 at 20 Ave. Apt 2, SF, CA
# 119  12/30  Sunset District apartment walk to UCSF, GG Par...
#
#                                                   link   price bedroom  sqft  \
# 0    https://sfbay.craigslist.org/sfc/apa/757348760...  $3,985     2br   920
# 1    https://sfbay.craigslist.org/sfc/apa/756546540...  $3,961     1br   745
# 2    https://sfbay.craigslist.org/sfc/apa/757348520...  $1,550     NaN   300
# 3    https://sfbay.craigslist.org/sfc/apa/756787962...  $7,435     3br  1146
# 4    https://sfbay.craigslist.org/sfc/apa/757156420...  $2,785     2br  1000
# ..                                                 ...     ...     ...   ...
# 115  https://sfbay.craigslist.org/sfc/apa/756918745...  $4,200     1br   607
# 116  https://sfbay.craigslist.org/sfc/apa/757273046...  $2,500     2br   860
# 117  https://sfbay.craigslist.org/sfc/apa/757342920...  $2,200     2br   NaN
# 118  https://sfbay.craigslist.org/sfc/apa/757343194...  $2,850     2br   860
# 119  https://sfbay.craigslist.org/sfc/apa/757343209...  $3,320     2br   940
#
#                   neighborhood bathroom  \
# 0    cole valley / ashbury hts        1
# 1           SOMA / south beach        1
# 2               lower nob hill        1
# 3           SOMA / south beach        2
# 4          alamo square / nopa      1.5
# ..                         ...      ...
# 115         financial district        1
# 116          sunset / parkside        1
# 117          sunset / parkside        1
# 118        richmond / seacliff        1
# 119        inner sunset / UCSF        1
#
#                                              amenities
# 0    [cats are OK - purrr, apartment, laundry in bl...
# 1    [EV charging, air conditioning, cats are OK - ...
# 2    [apartment, laundry in bldg, no smoking, no pa...
# 3    [EV charging, air conditioning, cats are OK - ...
# 4    [air conditioning, cats are OK - purrr, dogs a...
# ..                                                 ...
# 115  [air conditioning, apartment, w/d in unit, no ...
# 116  [open house dates, saturday 2022-12-31, sunday...
# 117  [apartment, laundry on site, no smoking, stree...
# 118  [open house dates, saturday 2022-12-31, sunday...
# 119  [apartment, laundry in bldg, attached garage, ...
#
# [120 rows x 9 columns]

# %%
# Exporting data to csv
df.to_csv('sf_data_raw.csv', index=False)

# %%
# Quit automated browser instance
browser.quit()
