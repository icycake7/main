# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
import numpy as np
import pandas as pd
from time import sleep
from random import randint

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.58M/6.58M [00:00<00:00, 40.8MB/s]

# %%
# Set url
url = 'https://boston.craigslist.org/search/apa#search=1~thumb~0~0'
browser.visit(url)

# Parse the HTML
html = browser.html
soup = bs(html, 'html.parser')

# find and extract relevant data
search = soup.find_all('div', class_='result-info')

# Create empty list to store scraped data
datatoget = []

# Loop through data found and extract relevant information
for (counter,link) in enumerate(search):

    # scrape dates
    dates = link.find_all('div', class_='meta')[0].text.split()[0][:3]

    # scrape titles
    titles = link.find_all('a', class_='titlestring')[0].text

    # scrape links
    links = link.find_all('a', class_='titlestring', href=True)[0]['href']

    # scrape prices
    prices = link.find_all('span', class_='priceinfo')[0].text

    # scrape neighborhoods
    neighborhoods = link.find('div', class_='supertitle').text

    # error handeling in case there are no bedrooms displayed
    try:
        bedrooms = link.find('span', class_='post-bedrooms').text

    except:
        bedrooms = np.nan

    # error handeling in case there are no sqft displayed
    try:
        sqft = link.find('span', class_='post-sqft').text.split()[0][:-3]
    except:
        sqft = np.nan
    
    # ensures that the server does not get overloaded with requests
    sleep(randint(1,5))  
    
    # visit each link seperately
    browser.visit(links)

    # after visiting link, extract bath and amenities data
    html = browser.html
    soup = bs(html, 'html.parser')
    baths = soup.find_all('p', class_='attrgroup')[0].text.split('\n')[1].split()[2][:-2]

    
    amenities = soup.find_all('p', class_='attrgroup')[1].text.split('\n')
    # list comprehension used to make sure no empty strings get added to the list
    all_amenities = [am for am in amenities if len(am) >= 1]
    
    # print statements to ensure that the correct data is scraped
    print(f'Listing Number: {counter+1}')
    print(f'Square Footage': {sqft}')
    print(f'price {prices}')
    print(f'Title {titles}')
    print(f'Date: {dates}')
    print(f'Number of Bedrooms {bedrooms})
    print(f'Neighborhood: {neighborhoods}')
    print(f'Number of Bathrooms: {baths}')
    print(f'Link: {links}')
    print(f'Amenities: {all_amenities}')

    # create dicitonary for our DataFrame
    data = {'date': dates,
            'title': titles,
            'link': links,
            'price': prices,
            'bedroom': bedrooms,
            'sqft': sqft,
            'neighborhood': neighborhoods,
            'bathroom': baths,
            'amenities': all_amenities}
    
    # append the data
    datatoget.append(data)
    
# Quit automated browser instance
browser.quit()
# Out:
# Listing Number: 0
# 900
# $2,300
# Five minute walk to Quincy Center
# 1/9
# 2br
# Quincy
# 1
# https://boston.craigslist.org/sob/apa/d/quincy-five-minute-walk-to-quincy-center/7576745505.html
# ['air conditioning', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking', 'rent period: monthly']
# Listing Number: 1
# nan
# $4,895
# ~Stunning Student Friendly 3 Bed 1.5 Bath~  w/ In Unit Laundry!
# 1/9
# 3br
# Brighton
# 1.5
# https://boston.craigslist.org/gbs/apa/d/brighton-stunning-student-friendly-bed/7576744301.html
# ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'street parking', 'rent period: monthly']
# Listing Number: 2
# nan
# $1,850
# SEPTEMBER - real live kitchen and private bathroom!
# 1/9
# nan
# boston/cambridge/brookline
# 1
# https://boston.craigslist.org/gbs/apa/d/boston-september-real-live-kitchen-and/7576737233.html
# ['apartment', 'laundry in bldg', 'no parking', 'rent period: monthly']
# Listing Number: 3
# 325
# $1,275
# 1 bedroom cottage
# 1/9
# 1br
# metro west
# 1
# https://boston.craigslist.org/bmw/apa/d/natick-bedroom-cottage/7576736567.html
# ['cottage/cabin', 'no laundry on site', 'off-street parking', 'rent period: monthly']
# Listing Number:
# https://boston.craigslist.org/gbs/apa/d/newtonville-bed-bath-heat-hw-prkg-large/7576408567.html
# ['broker fee details: 2595', 'apartment', 'laundry in bldg', 'listed by: FOLEY & SOULE ASSOCIATES', 'off-street parking', 'rent period: monthly']
# Listing Number: 117
# nan
# $2,495
# SUN DRENCHED  2 BED *** HEAT/HW/PRKG *** WALK TO RIVERSIDE T ***
# 1/8
# 2br
# NEWTON
# 1
# https://boston.craigslist.org/gbs/apa/d/newton-lower-falls-sun-drenched-bed/7576408420.html
# ['broker fee details: 2495', 'apartment', 'laundry in bldg', 'listed by: FOLEY & SOULE ASSOCIATES', 'off-street parking', 'rent period: monthly']
# Listing Number: 118
# nan
# $2,095
# SUNNY 1 BED ** HEAT/HW/PRKG ** NO LAST + NO SECURITY! *
# 1/8
# 1br
# NEWTON
# 1
# https://boston.craigslist.org/gbs/apa/d/auburndale-sunny-bed-heat-hw-prkg-no/7576408252.html
# ['broker fee details: 2095', 'apartment', 'laundry on site', 'listed by: FOLEY & SOULE ASSOCIATES', 'off-street parking', 'rent period: monthly']
# Listing Number: 119
# 900
# $1,900
# Townhome for Rent
# 1/8
# 2br
# Groton Massachusetts
# 1
# https://boston.craigslist.org/gbs/apa/d/ayer-townhome-for-rent/7576402950.html
# ['saturday 2023-01-14']

# %%
datatoget
# Out:
# [{'date': '1/9',
#   'title': 'Five minute walk to Quincy Center',
#   'link': 'https://boston.craigslist.org/sob/apa/d/quincy-five-minute-walk-to-quincy-center/7576745505.html',
#   'price': '$2,300',
#   'bedroom': '2br',
#   'sqft': '900',
#   'neighborhood': 'Quincy',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '~Stunning Student Friendly 3 Bed 1.5 Bath~  w/ In Unit Laundry!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brighton-stunning-student-friendly-bed/7576744301.html',
#   'price': '$4,895',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Brighton',
#   'bathroom': '1.5',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'SEPTEMBER - real live kitchen and private bathroom!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-september-real-live-kitchen-and/7576737233.html',
#   'price': '$1,850',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'boston/cambridge/brookline',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '1 bedroom cottage',
#   'link': 'https://boston.craigslist.org/bmw/apa/d/natick-bedroom-cottage/7576736567.html',
#   'price': '$1,275',
#   'bedroom': '1br',
#   'sqft': '325',
#   'neighborhood': 'metro west',
#   'bathroom': '1',
#   'amenities': ['cottage/cabin',
#    'no laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'filled with bright natural light - SEPTEMBER',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-filled-with-bright-natural-light/7576734244.html',
#   'price': '$1,850',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'boston/cambridge/brookline',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '~STUNNING~  3 Bed 3 Bath - W/D in UNIT w Parking!  Student OK!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brighton-stunning-bed-bath-d-in-unit/7576733629.html',
#   'price': '$3,900',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Brighton',
#   'bathroom': '3',
#   'amenities': ['cats are OK - purrr',
#    'condo',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '2 bed $2,400 March 1st - NO FEE!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/watertown-bed-2400-march-1st-no-fee/7576733121.html',
#   'price': '$2,400',
#   'bedroom': '2br',
#   'sqft': '1100',
#   'neighborhood': 'Watertown',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Large 4 bedroom/3 bathroom',
#   'link': 'https://boston.craigslist.org/nos/apa/d/winthrop-large-bedroom-bathroom/7576729374.html',
#   'price': '$4,500',
#   'bedroom': '4br',
#   'sqft': nan,
#   'neighborhood': 'Winthrop',
#   'bathroom': '3',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'APARTMENT FOR RENT',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brockton-apartment-for-rent/7576725536.html',
#   'price': '$1,500',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Brockton, MA',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '➤ NO BROKER FEE!!! ➤ Cozy East Boston 1 Bedroom!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/east-boston-no-broker-fee-cozy-east/7576724949.html',
#   'price': '$2,600',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'East Boston',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Amazing 3Bed 3Bath~$4995.',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-amazing-3bed-3bath4995/7576721317.html',
#   'price': '$4,995',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'boston/cambridge/brookline',
#   'bathroom': '3',
#   'amenities': ['townhouse',
#    'w/d in unit',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '***COLUMBIA RD SOUTH BOSTON PET FRIENDLY 3BED/1.5 BA-PARKING AVAIL!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/south-boston-columbia-rd-south-boston/7576717363.html',
#   'price': '$4,895',
#   'bedroom': '3br',
#   'sqft': '1060',
#   'neighborhood': 'Boston',
#   'bathroom': '1.5',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '****NORTH END FLEET ST PENTHOUSE 4BED/3BED RENTAL APARTMENT!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-north-end-fleet-st-penthouse/7576712719.html',
#   'price': '$7,000',
#   'bedroom': '4br',
#   'sqft': '1780',
#   'neighborhood': 'Boston',
#   'bathroom': '3',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Luxury 2-Bedroom Apartments - Pool - Walk to T - Avail. Now!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/belmont-luxury-bedroom-apartments-pool/7576711960.html',
#   'price': '$3,450',
#   'bedroom': '2br',
#   'sqft': '1073',
#   'neighborhood': 'Belmont',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': 'Luxury 1-Beds - Pool - Walk to T - Avail. Now!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/belmont-luxury-beds-pool-walk-to-avail/7576711674.html',
#   'price': '$2,650',
#   'bedroom': '1br',
#   'sqft': '708',
#   'neighborhood': 'Belmont / Cambridge',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'A Beautiful Apartment For Rent!',
#   'link': 'https://boston.craigslist.org/nos/apa/d/lynn-beautiful-apartment-for-rent/7576705989.html',
#   'price': '$3,200',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Lynn',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'RENOVATED, 3Br+2Ba, 1-Car Garage, FULL Amenities',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/chelsea-renovated-3br2ba-car-garage/7576704891.html',
#   'price': '$2,850',
#   'bedroom': '3br',
#   'sqft': '1450',
#   'neighborhood': 'Chelsea, MA',
#   'bathroom': '2',
#   'amenities': ['condo',
#    'w/d in unit',
#    'no smoking',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '****2/1/23 CHESTNUT HILL AVE-BRIGHTON PET-FRIENDLY 1BED RENTAL',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brighton-chestnut-hill-ave-brighton-pet/7576698547.html',
#   'price': '$2,250',
#   'bedroom': '1br',
#   'sqft': '490',
#   'neighborhood': 'Brighton',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Unbeatable 2 bed in the heart of Cambridgeport',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-unbeatable-bed-in-the-heart/7576697689.html',
#   'price': '$3,900',
#   'bedroom': '2br',
#   'sqft': '1100',
#   'neighborhood': 'Cambridge',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Updated 2 bed townhouse',
#   'link': 'https://boston.craigslist.org/sob/apa/d/south-walpole-updated-bed-townhouse/7576694950.html',
#   'price': '$2,450',
#   'bedroom': '2br',
#   'sqft': '1200',
#   'neighborhood': 'Dorchester',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'townhouse',
#    'w/d hookups',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '****3/31/23 HIGHLAND AVE SOMERVILLE STUDIO-HEAT & HOT WATER INCLUDED!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/somerville-highland-ave-somerville/7576693015.html',
#   'price': '$1,995',
#   'bedroom': nan,
#   'sqft': '405',
#   'neighborhood': 'Somerville',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Melrose Green St 2 Bed For 1-16-23 Prkng+Lndry+No Fee!!',
#   'link': 'https://boston.craigslist.org/nos/apa/d/melrose-melrose-green-st-bed-for/7576691481.html',
#   'price': '$1,850',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'north shore',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '3 units each 3 bedroom/1 bath available  2/1/23',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-units-each-bedroom-bath/7576689257.html',
#   'price': '$3,625',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Jamaica Plain, MA',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '****CHESTNUT HILL BRIGHTON PET-FRIENDLY STUDIO! FEBRUARY 2023!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brighton-chestnut-hill-brighton-pet/7576687109.html',
#   'price': '$2,200',
#   'bedroom': nan,
#   'sqft': '430',
#   'neighborhood': 'Boston',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '✨STATE OF THE ART BOSTON LUXURY! GYM, POOL! ✨',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/south-boston-state-of-the-art-boston/7576684463.html',
#   'price': '$2,300',
#   'bedroom': nan,
#   'sqft': '640',
#   'neighborhood': 'Boston Walk to Redline by South Boston',
#   'bathroom': '1',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': 'Beautiful 3BD/1BR apartment. In unit Laundry',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/medford-beautiful-3bd-1br-apartment-in/7576682739.html',
#   'price': '$3,200',
#   'bedroom': '3br',
#   'sqft': '1000',
#   'neighborhood': 'Somerville',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'SEPTEMBER -  Studio with BALCONY - September',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/allston-september-studio-with-balcony/7576678644.html',
#   'price': '$1,775',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Allston',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'condo',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '✨IMPRESSIVE FULL SERVICE 2BED/2BATH W/D, GYM, POOL, ✨',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/malden-impressive-full-service-2bed/7576673665.html',
#   'price': '$2,967',
#   'bedroom': '2br',
#   'sqft': '1000',
#   'neighborhood': 'North of Boston Walk to Subway',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'broker fee details: $1000',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '1 Bedroom-Cheerful apartment on 2nd floor in 4 unit building',
#   'link': 'https://boston.craigslist.org/sob/apa/d/norwood-bedroom-cheerful-apartment-on/7576667868.html',
#   'price': '$1,150',
#   'bedroom': '1br',
#   'sqft': '450',
#   'neighborhood': 'NORWOOD, MA',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'ENCHANTING 1BED, W/D, GYM, POOL, WALK TO TRAIN',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/malden-enchanting-1bed-d-gym-pool-walk/7576666522.html',
#   'price': '$2,152',
#   'bedroom': '1br',
#   'sqft': '681',
#   'neighborhood': 'North of Boston Walk to Subway',
#   'bathroom': '1',
#   'amenities': ['broker fee details: $500',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'REVERE DEAD END ROAD Near shopping/pub transp/hghwys/Logan',
#   'link': 'https://boston.craigslist.org/nos/apa/d/revere-revere-dead-end-road-near/7576665417.html',
#   'price': '$1,824',
#   'bedroom': '1br',
#   'sqft': '700',
#   'neighborhood': 'Revere',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '2 Bedroom Apartment',
#   'link': 'https://boston.craigslist.org/nos/apa/d/malden-bedroom-apartment/7576662968.html',
#   'price': '$2,250',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Malden',
#   'bathroom': '1',
#   'amenities': ['application fee details: $25 Application and Credit Report Fee',
#    'cats are OK - purrr',
#    'apartment',
#    'no laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Avail 2bdrms/with one bath/Cambridgeport/Central sq! $3200',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-avail-2bdrms-with-one-bath/7576308523.html',
#   'price': '$3,200',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Cambridgeport',
#   'bathroom': '1',
#   'amenities': ['broker fee details: full fee',
#    'furnished',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Avail for 1/1/23, a 5 bdrm/5.5 bath 13 rms! hdwdfl/gas ht! Eat in st',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/medford-avail-for-5-bdrm-55-bath-13-rms/7576319031.html',
#   'price': '$5,600',
#   'bedroom': '5br',
#   'sqft': nan,
#   'neighborhood': 'Medford',
#   'bathroom': '5.5',
#   'amenities': ['broker fee details: full fee',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '$2,600 / 4br - 1st Floor Apartment',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brockton-br-1st-floor-apartment/7576652186.html',
#   'price': '$2,600',
#   'bedroom': '4br',
#   'sqft': '1100',
#   'neighborhood': 'Brockton',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': "Perfect Spot! Pool-Gym-Yoga! Pet Friendly! You'll Love Living Here!",
#   'link': 'https://boston.craigslist.org/gbs/apa/d/lynn-perfect-spot-pool-gym-yoga-pet/7576651034.html',
#   'price': '$2,225',
#   'bedroom': '1br',
#   'sqft': '652',
#   'neighborhood': 'Lynn',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Charming 1 bdr, Harvard Sq., hw included, pet ok',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-charming-bdr-harvard-sq-hw/7576650735.html',
#   'price': '$2,050',
#   'bedroom': '1br',
#   'sqft': '1050',
#   'neighborhood': 'Cambridge',
#   'bathroom': '1',
#   'amenities': ['broker fee details: 2050',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'listed by: Senné Residential',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '**NO Fee** Quincy: 1 Bed w Kitchen Island & Laundry. Walk to Redline.',
#   'link': 'https://boston.craigslist.org/sob/apa/d/quincy-no-fee-quincy-bed-kitchen-island/7576648767.html',
#   'price': '$2,399',
#   'bedroom': '1br',
#   'sqft': '750',
#   'neighborhood': 'Quincy Center',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Granite Street Crossing - Affordable 3-Bedroom Townhouses',
#   'link': 'https://boston.craigslist.org/nos/apa/d/rockport-granite-street-crossing/7576646766.html',
#   'price': '$2,188',
#   'bedroom': '3br',
#   'sqft': '1450',
#   'neighborhood': 'Rockport',
#   'bathroom': '1.5',
#   'amenities': ['air conditioning',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': 'FULL SERVICE 2BED/2BH W/D, GYM, LOUNGE, PET OK - WALK TO SOUTH STATION',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-full-service-2bed-2bh-d-gym/7576646646.html',
#   'price': '$3,731',
#   'bedroom': '2br',
#   'sqft': '1050',
#   'neighborhood': 'Downtown Boston - Walk to South Station - NO BROKER FEE',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Granite Street Crossing - Affordable 2-Bedroom Apartments',
#   'link': 'https://boston.craigslist.org/nos/apa/d/rockport-granite-street-crossing/7576644625.html',
#   'price': '$1,893',
#   'bedroom': '2br',
#   'sqft': '1070',
#   'neighborhood': 'Rockport',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': 'Granite Street Crossing - Affordable Senior Studio Apartments',
#   'link': 'https://boston.craigslist.org/nos/apa/d/rockport-granite-street-crossing/7576641711.html',
#   'price': '$1,473',
#   'bedroom': nan,
#   'sqft': '358',
#   'neighborhood': 'Rockport, MA',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': 'Sunny Mod Style quiet street inc. Heat, HW+ Parking Spot.  Avail. NOW!',
#   'link': 'https://boston.craigslist.org/bmw/apa/d/newton-lower-falls-sunny-mod-style/7576639797.html',
#   'price': '$2,495',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Newton - Lower Falls on Wellesey Line',
#   'bathroom': '1',
#   'amenities': ["broker fee details: one month's rent",
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'listed by: Harvard Real Estate',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Nice second floor in house: ALL UTILITIES INCLUDED!. Avail. Now.',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/newton-nice-second-floor-in-house-all/7576639142.html',
#   'price': '$2,700',
#   'bedroom': '2br',
#   'sqft': '1000',
#   'neighborhood': 'Newton Corner',
#   'bathroom': '1',
#   'amenities': ["broker fee details: one month's rent",
#    'cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'listed by: Harvard Real Estate',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Modern Style nice corner: heat, hot water+park spot inc. Avail Now!',
#   'link': 'https://boston.craigslist.org/bmw/apa/d/auburndale-modern-style-nice-corner/7576638437.html',
#   'price': '$2,395',
#   'bedroom': '2br',
#   'sqft': '775',
#   'neighborhood': 'Newton - Aburndale area',
#   'bathroom': '1',
#   'amenities': ["broker fee details: one month's rent",
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'listed by: Harvard Real Estate',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Two Bedroom Apt. Includes Heat, Hot Water, and Electric',
#   'link': 'https://boston.craigslist.org/sob/apa/d/hanover-two-bedroom-apt-includes-heat/7576631126.html',
#   'price': '$1,950',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Bridgewater',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d hookups',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Large apartment w/ new kitchen - near buses',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/dorchester-large-apartment-new-kitchen/7576630085.html',
#   'price': '$895',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Dorchester',
#   'bathroom': 'shared',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Ready to Rent in North Quincy! Start ASAP.',
#   'link': 'https://boston.craigslist.org/sob/apa/d/quincy-ready-to-rent-in-north-quincy/7576629054.html',
#   'price': '$2,200',
#   'bedroom': '1br',
#   'sqft': '855',
#   'neighborhood': 'Quincy',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': '*JP Luxury Studio Close to T Stop- 1.5 FREE MONTHS* & No Fee!*',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/jamaica-plain-jp-luxury-studio-close-to/7576627110.html',
#   'price': '$2,200',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Jamaica Plain',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '*NO FEE* Huge Allston February Studio, HEAT/HW INC, Train, Laundry!!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/allston-no-fee-huge-allston-february/7576625807.html',
#   'price': '$1,725',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Allston',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Porter 3 bed/2 bath, granite kit, patio, parking! NO FEE! Avail 2/1',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/somerville-porter-bed-bath-granite-kit/7576623132.html',
#   'price': '$3,600',
#   'bedroom': '3br',
#   'sqft': '1600',
#   'neighborhood': 'Porter Square, Somerville',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'MALDEN - Finest Luxury! Pool - Gym - Yoga - Grilling - Dog Park!!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/malden-malden-finest-luxury-pool-gym/7576621492.html',
#   'price': '$2,395',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Malden',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '3 bed / 2 bath, off street parking, laundry in unit, PET FRIENDLY',
#   'link': 'https://boston.craigslist.org/bmw/apa/d/marlborough-bed-bath-off-street-parking/7576610215.html',
#   'price': '$2,900',
#   'bedroom': '3br',
#   'sqft': '1600',
#   'neighborhood': 'French Hill, Marlborough',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'January move-in - room in apt building',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-january-move-in-room-in-apt/7576602540.html',
#   'price': '$1,395',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Cambridge',
#   'bathroom': 'shared',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'North End Gem - VERY NICE OVERSIZED 1 BEDROOM - Central Air, Laundry',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/charlestown-north-end-gem-very-nice/7576598637.html',
#   'price': '$2,650',
#   'bedroom': '1br',
#   'sqft': '600',
#   'neighborhood': 'NORTH END ~ March 1st',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'North End Junior 1 Bed - Roof Deck, Central Air, Laundry - HAS IT ALL!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-north-end-junior-bed-roof-deck/7576597152.html',
#   'price': '$2,400',
#   'bedroom': nan,
#   'sqft': '450',
#   'neighborhood': 'NORTH END ~ March 1st',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'NEWLY COMPLETED LUXURY PRIVATE ROOM AVAILABLE- NO BROKERS FEE',
#   'link': 'https://boston.craigslist.org/nos/apa/d/lynn-newly-completed-luxury-private/7576595148.html',
#   'price': '$1,000',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Lynn, MA',
#   'bathroom': '9+',
#   'amenities': ['furnished',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'COMPLETELY RENOVATED LUXURY PRIVATE ROOMS FOR RENT',
#   'link': 'https://boston.craigslist.org/nos/apa/d/lynn-completely-renovated-luxury/7576594360.html',
#   'price': '$1,000',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Lynn, MA',
#   'bathroom': '9+',
#   'amenities': ['furnished',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'NEWLY RELEASED AND COMPLETED PRIVATE ROOM FOR RENT- NO BROKER FEE',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/lynn-newly-released-and-completed/7576593614.html',
#   'price': '$1,000',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Lynn, MA',
#   'bathroom': '9+',
#   'amenities': ['furnished',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'FURNISHED PRIVATE ROOM FOR RENT- NEWLY RENOVATED',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/lynn-furnished-private-room-for-rent/7576592767.html',
#   'price': '$1,000',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Lynn, MA',
#   'bathroom': '9+',
#   'amenities': ['furnished',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'COMPLETELY RENOVATED PRIVATE ROOM FOR RENT- ALL UTILITIES INCLUDED',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/lynn-completely-renovated-private-room/7576591381.html',
#   'price': '$1,000',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Lynn, MA',
#   'bathroom': '9+',
#   'amenities': ['furnished',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Furnished Studio Available Now!',
#   'link': 'https://boston.craigslist.org/nwb/apa/d/lowell-furnished-studio-available-now/7576589612.html',
#   'price': '$2,300',
#   'bedroom': nan,
#   'sqft': '400',
#   'neighborhood': 'Lowell, Massachusetts',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'furnished',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Fully furnished 2 bed-Single family house , Short Term-Renovated Harva',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/watertown-fully-furnished-bed-single/7576589397.html',
#   'price': '$3,600',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Belmont',
#   'bathroom': '2',
#   'amenities': ['broker fee details: 3600',
#    'apartment',
#    'w/d in unit',
#    'listed by: Bayside Realty',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Fabulous MASSIVE 2 bed in a house for 9/1/23- VERY RARE!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/allston-fabulous-massive-bed-in-house/7576589357.html',
#   'price': '$2,900',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Allston',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Malden Square Location',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/malden-malden-square-location/7576585124.html',
#   'price': '$1,750',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Malden',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '**South Boston 6 Month Sublease with 12 month renewal potential**',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/south-boston-south-boston-month/7576584823.html',
#   'price': '$2,600',
#   'bedroom': '2br',
#   'sqft': '1200',
#   'neighborhood': 'South Boston',
#   'bathroom': '1.5',
#   'amenities': ['air conditioning',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'The Eddy - need someone to take over lease ASAP',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-the-eddy-need-someone-to-take/7576581454.html',
#   'price': '$2,784',
#   'bedroom': '1br',
#   'sqft': '650',
#   'neighborhood': 'East Boston',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': 'Excellent 2BD!10 min to Central SQ T!In unit Laundry!Partly Furnished!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-excellent-2bd10-min-to/7576578266.html',
#   'price': '$3,200',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Central Square',
#   'bathroom': '1',
#   'amenities': ['broker fee details: $3200',
#    'apartment',
#    'w/d in unit',
#    'listed by: Maven Realty',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Beautiful 2 bed Condo 2 baths, great view-Heated, pkg avail-ASAP',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-beautiful-bed-condo-baths/7576576124.html',
#   'price': '$3,500',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Cambridge, Central sq, MIT, Harvard sq',
#   'bathroom': '2',
#   'amenities': ['broker fee details: 3500',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'listed by: Bayside Realty',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Renovated, 2 Bed Plus-Harvard sq-HBS area , porch, laundry A/c-ASAP-Fe',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-renovated-bed-plus-harvard-sq/7576565245.html',
#   'price': '$3,400',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Cambridge, HBS, Harvard sq, Central sq',
#   'bathroom': '1',
#   'amenities': ['broker fee details: 3400',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'listed by: Bayside Realty',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Fabulous MASSIVE 4 bed 2 bath for 9/1/2023!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/allston-fabulous-massive-bed-bath-for/7576564512.html',
#   'price': '$4,600',
#   'bedroom': '4br',
#   'sqft': nan,
#   'neighborhood': 'Allston',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Sunny 1 Bedroom Apartment',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/medford-sunny-bedroom-apartment/7576562153.html',
#   'price': '$1,750',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Arlington',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Location PLUS..Wollaston.',
#   'link': 'https://boston.craigslist.org/sob/apa/d/quincy-location-pluswollaston/7576558381.html',
#   'price': '$2,095',
#   'bedroom': '2br',
#   'sqft': '800',
#   'neighborhood': 'Quincy',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Spacious two bedroom/TWO full bathrooms',
#   'link': 'https://boston.craigslist.org/sob/apa/d/quincy-spacious-two-bedroom-two-full/7576557742.html',
#   'price': '$2,395',
#   'bedroom': '2br',
#   'sqft': '920',
#   'neighborhood': 'Quincy',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'September 1st  1 Bed 1 Bath**Hot Water Inc',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-september-1st-bed-bathhot-water/7576553621.html',
#   'price': '$2,350',
#   'bedroom': '1br',
#   'sqft': '600',
#   'neighborhood': 'North End',
#   'bathroom': '1',
#   'amenities': ['broker fee details: one month',
#    'apartment',
#    'no laundry on site',
#    'listed by: Carmine Federico - Greater Metropolitan Real Estate',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Large renovated JUNE 1st Mission Hill 1 bed!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brookline-village-large-renovated-june/7576552892.html',
#   'price': '$2,045',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Mission Hill',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Top Flr, Cozy, 2 BR/1 BA Apt nr Harv. Law! Hdwd, Ht/hw incl! 2/1~',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-top-flr-cozy-br-ba-apt-nr/7576552839.html',
#   'price': '$2,600',
#   'bedroom': '2br',
#   'sqft': '850',
#   'neighborhood': 'Sacramento St./ Nr Harvard Sq.',
#   'bathroom': '1',
#   'amenities': ['broker fee details: 2500.',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'listed by: Kim/ Senne RE',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'CUTE & CLASSY CAMBRIDGE FULL SERVICE 2BED/2BH, W/D, GYM, ROOFDECK',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-cute-classy-cambridge-full/7576552023.html',
#   'price': '$4,849',
#   'bedroom': '2br',
#   'sqft': '1194',
#   'neighborhood': 'Cambridge Walk to Subway -Shuttle to MIT',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'HEAT INCLUDED. PRIVATE PATIO. FITNESS CENTER. POOL!',
#   'link': 'https://boston.craigslist.org/nwb/apa/d/lowell-heat-included-private-patio/7576551835.html',
#   'price': '$1,986',
#   'bedroom': '1br',
#   'sqft': '560',
#   'neighborhood': 'CHELMSFORD',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Hull Quiet Side-Street One Block To Beach And Bus',
#   'link': 'https://boston.craigslist.org/sob/apa/d/hull-hull-quiet-side-street-one-block/7576546605.html',
#   'price': '$1,550',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'south shore',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Amazing 3br in Fenway!!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-amazing-3br-in-fenway/7576545697.html',
#   'price': '$6,500',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Fenway',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'LUXURY Renovated Beacon Street 3Bed/2Bath, GARAGE PKNG, A/C, May 15th!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brookline-village-luxury-renovated/7576540925.html',
#   'price': '$4,700',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Beacon Street/Brookline/Washington Square',
#   'bathroom': '2',
#   'amenities': ["broker fee details: One Month's Rent",
#    'condo',
#    'laundry in bldg',
#    'listed by: Heidi Shenker Real Estate',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'a beautiful loft',
#   'link': 'https://boston.craigslist.org/nos/apa/d/wakefield-beautiful-loft/7576538199.html',
#   'price': '$1,600',
#   'bedroom': '1br',
#   'sqft': '800',
#   'neighborhood': 'downtown wakefield near t',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'apartment',
#    'laundry in bldg',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Partial Fee! Modern 2 BR nr MIT w/ 24-hr Concierge, Incl Heat & H.W.',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-partial-fee-modern-br-nr-mit/7576537791.html',
#   'price': '$3,270',
#   'bedroom': '2br',
#   'sqft': '700',
#   'neighborhood': 'Cambridge - Kendall Square',
#   'bathroom': '1',
#   'amenities': ['broker fee details: $2270',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'listed by: Senné Residential of Cambridge',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Fantastic Studio w/Alcove in Fenway!!!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-fantastic-studio-alcove-in-fenway/7576528999.html',
#   'price': '$1,850',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Kenmore',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Lovely Studio in Fenway!!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-lovely-studio-in-fenway/7576527979.html',
#   'price': '$2,100',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Kenmore',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Get this 3br in Fenway!!!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-get-this-3br-in-fenway/7576526909.html',
#   'price': '$3,600',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Kenmore',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Awesome 3br in Fenway!!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-awesome-3br-in-fenway/7576521657.html',
#   'price': '$3,800',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Fenway',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Totally remodeled 3 bedroom with 6 rooms, New Hardwood Floors',
#   'link': 'https://boston.craigslist.org/nos/apa/d/malden-totally-remodeled-bedroom-with/7576521290.html',
#   'price': '$3,000',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Malden',
#   'bathroom': '1',
#   'amenities': ['broker fee details: 1500',
#    'apartment',
#    'no laundry on site',
#    'listed by: Robert Klemm Broker',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Quick 99, 105 or 106 Bus to Orange Line or Encore Casino',
#   'link': 'https://boston.craigslist.org/nos/apa/d/everett-quick-or-106-bus-to-orange-line/7576520873.html',
#   'price': '$2,800',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Everett',
#   'bathroom': '1',
#   'amenities': ['broker fee details: 1400',
#    'apartment',
#    'no laundry on site',
#    'listed by: Robert Klemm Broker',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '2nd Floor HUGE Industrial Loft Style Apt w Laundry**NO Broker FEE**',
#   'link': 'https://boston.craigslist.org/sob/apa/d/quincy-2nd-floor-huge-industrial-loft/7576519263.html',
#   'price': '$2,500',
#   'bedroom': '2br',
#   'sqft': '1014',
#   'neighborhood': 'Quincy',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'SEPT 2023-Audubon Circle 2 bed. H/HW inc. 1 Month Fee',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-sept-2023-audubon-circle-bed-hw/7576515431.html',
#   'price': '$3,000',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Fenway',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Sophisticated Haven In A Premium Lifestyle Enclave - 7 Island Rd',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/medway-sophisticated-haven-in-premium/7576512884.html',
#   'price': '$3,097',
#   'bedroom': '3br',
#   'sqft': '1666',
#   'neighborhood': 'Franklin',
#   'bathroom': '2',
#   'amenities': ['house',
#    'w/d hookups',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '4/1!Modern BLDG 2BD! HT/ Incl!Parking!8 min to Davis T!Laundry!Dog NEG',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-1modern-bldg-2bd-ht/7576510650.html',
#   'price': '$3,200',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Davis Sq/N.Cambridge',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'broker fee details: $3200',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'listed by: Maven Realty',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'SEPT 2023-Awesome Brighton Pet Friendly 1 bed.',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brighton-sept-2023-awesome-brighton-pet/7576510333.html',
#   'price': '$1,950',
#   'bedroom': nan,
#   'sqft': nan,
#   'neighborhood': 'Brighton',
#   'bathroom': '1',
#   'amenities': ['dogs are OK - wooof',
#    'condo',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '2 Bedeoom',
#   'link': 'https://boston.craigslist.org/nos/apa/d/salem-bedeoom/7576505928.html',
#   'price': '$1,800',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Salem',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'One bedroom Modern Townhouse - Near Major Highways',
#   'link': 'https://boston.craigslist.org/nwb/apa/d/lowell-one-bedroom-modern-townhouse/7576494997.html',
#   'price': '$1,510',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Lowell/TewksburyLine/NearBillerica&Chelmsford',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d hookups',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'Furnished 1 Bedroom unit NEXT TO HARVARD',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-furnished-bedroom-unit-next/7576490023.html',
#   'price': '$2,550',
#   'bedroom': '1br',
#   'sqft': '720',
#   'neighborhood': 'Cambridge',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'WOW FULL SERVICE LUXURY! W/D, GYM, BACK BAY! FREE GAS/HOT WATER & WIFI',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-wow-full-service-luxury-d-gym/7576488502.html',
#   'price': '$3,475',
#   'bedroom': nan,
#   'sqft': '508',
#   'neighborhood': 'Back Bay of Boston - Walk to Boston Commons / Public Garden',
#   'bathroom': '1',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': '❤❤❤HARVARD SINGLE FAMILY 3 BEDS 3 BATHS AND A LOFT...PETS OK',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-harvard-single-family-beds/7576487108.html',
#   'price': '$5,000',
#   'bedroom': '3br',
#   'sqft': '2200',
#   'neighborhood': 'CAMBRIDGE/HURON VILLAGE',
#   'bathroom': '3',
#   'amenities': ['broker fee details: 5000',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'house',
#    'w/d in unit',
#    'listed by: BONNIE',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'NO FEE!! 4 BEDROOM 2 BATH HOUSE/PETS OK/COHASSET/GORGEOUS',
#   'link': 'https://boston.craigslist.org/sob/apa/d/cohasset-no-fee-bedroom-bath-house-pets/7576486977.html',
#   'price': '$4,500',
#   'bedroom': '4br',
#   'sqft': nan,
#   'neighborhood': 'COHASSET',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'house',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '3 BEDROOM 2 BATH..HARVARD..CATS OK..PARKING',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-bedroom-bathharvardcats/7576486892.html',
#   'price': '$3,600',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'CAMBRIDGE',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'broker fee details: 3600',
#    'cats are OK - purrr',
#    'house',
#    'w/d in unit',
#    'listed by: BONNIE',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'LARGE ROOM..SULLIVAN/UNION..GREEN+ORANGELINE..MIT..HARVARD..MGH.PETS O',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/somerville-large-roomsullivan/7576486816.html',
#   'price': '$1,200',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'SOMERVILLE',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'broker fee details: 1200',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'listed by: BONNIE',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': 'LARGE ROOM IN A HOUSE/MIT/EAST CAMBRIDGE/KENDALL/MIT/MGH/REDLINE',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-large-room-in-house-mit-east/7576486729.html',
#   'price': '$1,250',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'CAMBRIDGE',
#   'bathroom': '1',
#   'amenities': ['broker fee details: 1250',
#    'furnished',
#    'house',
#    'w/d in unit',
#    'listed by: BONNIE',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/9',
#   'title': '2BR UNIT CLOSE TO SULLIVAN STATION! WITH W&D IN UNIT! GREAT DEAL!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/charlestown-2br-unit-close-to-sullivan/7576483766.html',
#   'price': '$4,498',
#   'bedroom': '2br',
#   'sqft': '1010',
#   'neighborhood': 'Charlestown',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'broker fee details: 0',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'listed by: Hartley Realty Group',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': '2BR UNIT CLOSE TO SULLIVAN STATION! WITH W&D IN UNIT! GREAT DEAL!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/charlestown-2br-unit-close-to-sullivan/7576483654.html',
#   'price': '$3,971',
#   'bedroom': '2br',
#   'sqft': '860',
#   'neighborhood': 'Charlestown',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'broker fee details: 0',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'listed by: Hartley Realty Group',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': '1BR UNIT CLOSE TO SULLIVAN STATION! WITH W&D IN UNIT! GREAT DEAL!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/charlestown-1br-unit-close-to-sullivan/7576483507.html',
#   'price': '$3,199',
#   'bedroom': '1br',
#   'sqft': '585',
#   'neighborhood': 'Charlestown',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'broker fee details: 0',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'listed by: Hartley Realty Group',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': '1BR UNIT CLOSE TO SULLIVAN STATION! WITH W&D IN UNIT! GREAT DEAL!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/charlestown-1br-unit-close-to-sullivan/7576483387.html',
#   'price': '$3,174',
#   'bedroom': '1br',
#   'sqft': '756',
#   'neighborhood': 'Charlestown',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'broker fee details: 0',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'listed by: Hartley Realty Group',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': 'STUDIO UNIT CLOSE TO SULLIVAN STATION! WITH W&D IN UNIT! GREAT DEAL!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/charlestown-studio-unit-close-to/7576483279.html',
#   'price': '$2,712',
#   'bedroom': nan,
#   'sqft': '496',
#   'neighborhood': 'Charlestown',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'broker fee details: 0',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'listed by: Hartley Realty Group',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/9',
#   'title': 'STUDIO UNIT CLOSE TO SULLIVAN STATION! WITH W&D IN UNIT! GREAT DEAL!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/charlestown-studio-unit-close-to/7576483146.html',
#   'price': '$2,702',
#   'bedroom': nan,
#   'sqft': '526',
#   'neighborhood': 'Charlestown',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'broker fee details: 0',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'listed by: Hartley Realty Group',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/8',
#   'title': 'LUXURY Renovated Beacon Street 3Bed/2Bath, GARAGE PKNG, A/C, May 15th!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/brookline-village-luxury-renovated/7576445737.html',
#   'price': '$4,700',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Beacon Street/Brookline/Washington Square',
#   'bathroom': '2',
#   'amenities': ["broker fee details: One Month's Rent",
#    'condo',
#    'laundry in bldg',
#    'listed by: Heidi Shenker Real Estate',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': 'Nice and fully renovated 2Bd in Winter Hill',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/somerville-nice-and-fully-renovated-2bd/7576441194.html',
#   'price': '$2,600',
#   'bedroom': '2br',
#   'sqft': '860',
#   'neighborhood': 'Somerville',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': 'Immediate Availability 2 Bed, 2 Bath  in Central Square - $3,100',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/cambridge-immediate-availability-bed/7576439802.html',
#   'price': '$3,100',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Central Square, Cambridge',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': 'Renovated 2BR w Parking Near Harvard Square',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/boston-renovated-2br-parking-near/7576433730.html',
#   'price': '$3,700',
#   'bedroom': '2br',
#   'sqft': '825',
#   'neighborhood': 'Harvard Square',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': '**VIDEO** RENOVATED, TWO BEDROOM APARTMENT, NEW KITCHEN & BATH, NO FEE',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/watertown-video-renovated-two-bedroom/7576412527.html',
#   'price': '$2,695',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Belmont, Cambridge, Watertown',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': 'Apt for rent',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/roxbury-apt-for-rent/7576408683.html',
#   'price': '$3,500',
#   'bedroom': '4br',
#   'sqft': nan,
#   'neighborhood': 'Roxbury, Mass',
#   'bathroom': '1.5',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'w/d hookups',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': '2 BED 2 BATH || HEAT/HW/PRKG || LARGE CLOSETS || NO LAST-NO SECURITY!',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/newtonville-bed-bath-heat-hw-prkg-large/7576408567.html',
#   'price': '$2,595',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'NEWTON',
#   'bathroom': '2',
#   'amenities': ['broker fee details: 2595',
#    'apartment',
#    'laundry in bldg',
#    'listed by: FOLEY & SOULE ASSOCIATES',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': 'SUN DRENCHED  2 BED *** HEAT/HW/PRKG *** WALK TO RIVERSIDE T ***',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/newton-lower-falls-sun-drenched-bed/7576408420.html',
#   'price': '$2,495',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'NEWTON',
#   'bathroom': '1',
#   'amenities': ['broker fee details: 2495',
#    'apartment',
#    'laundry in bldg',
#    'listed by: FOLEY & SOULE ASSOCIATES',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': 'SUNNY 1 BED ** HEAT/HW/PRKG ** NO LAST + NO SECURITY! *',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/auburndale-sunny-bed-heat-hw-prkg-no/7576408252.html',
#   'price': '$2,095',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'NEWTON',
#   'bathroom': '1',
#   'amenities': ['broker fee details: 2095',
#    'apartment',
#    'laundry on site',
#    'listed by: FOLEY & SOULE ASSOCIATES',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/8',
#   'title': 'Townhome for Rent',
#   'link': 'https://boston.craigslist.org/gbs/apa/d/ayer-townhome-for-rent/7576402950.html',
#   'price': '$1,900',
#   'bedroom': '2br',
#   'sqft': '900',
#   'neighborhood': 'Groton Massachusetts',
#   'bathroom': '1',
#   'amenities': ['saturday 2023-01-14']}]

# %%
# creating DataFrame
df = pd.DataFrame(datatoget)
df
# Out:
#     date                                              title  \
# 0    1/9                  Five minute walk to Quincy Center
# 1    1/9  ~Stunning Student Friendly 3 Bed 1.5 Bath~  w/...
# 2    1/9  SEPTEMBER - real live kitchen and private bath...
# 3    1/9                                  1 bedroom cottage
# 4    1/9       filled with bright natural light - SEPTEMBER
# ..   ...                                                ...
# 115  1/8                                       Apt for rent
# 116  1/8  2 BED 2 BATH || HEAT/HW/PRKG || LARGE CLOSETS ...
# 117  1/8  SUN DRENCHED  2 BED *** HEAT/HW/PRKG *** WALK ...
# 118  1/8  SUNNY 1 BED ** HEAT/HW/PRKG ** NO LAST + NO SE...
# 119  1/8                                  Townhome for Rent
#
#                                                   link   price bedroom sqft  \
# 0    https://boston.craigslist.org/sob/apa/d/quincy...  $2,300     2br  900
# 1    https://boston.craigslist.org/gbs/apa/d/bright...  $4,895     3br  NaN
# 2    https://boston.craigslist.org/gbs/apa/d/boston...  $1,850     NaN  NaN
# 3    https://boston.craigslist.org/bmw/apa/d/natick...  $1,275     1br  325
# 4    https://boston.craigslist.org/gbs/apa/d/boston...  $1,850     NaN  NaN
# ..                                                 ...     ...     ...  ...
# 115  https://boston.craigslist.org/gbs/apa/d/roxbur...  $3,500     4br  NaN
# 116  https://boston.craigslist.org/gbs/apa/d/newton...  $2,595     2br  NaN
# 117  https://boston.craigslist.org/gbs/apa/d/newton...  $2,495     2br  NaN
# 118  https://boston.craigslist.org/gbs/apa/d/auburn...  $2,095     1br  NaN
# 119  https://boston.craigslist.org/gbs/apa/d/ayer-t...  $1,900     2br  900
#
#                    neighborhood bathroom  \
# 0                        Quincy        1
# 1                      Brighton      1.5
# 2    boston/cambridge/brookline        1
# 3                    metro west        1
# 4    boston/cambridge/brookline        1
# ..                          ...      ...
# 115               Roxbury, Mass      1.5
# 116                      NEWTON        2
# 117                      NEWTON        1
# 118                      NEWTON        1
# 119        Groton Massachusetts        1
#
#                                              amenities
# 0    [air conditioning, apartment, laundry in bldg,...
# 1    [cats are OK - purrr, dogs are OK - wooof, apa...
# 2    [apartment, laundry in bldg, no parking, rent ...
# 3    [cottage/cabin, no laundry on site, off-street...
# 4    [apartment, laundry in bldg, no parking, rent ...
# ..                                                 ...
# 115  [cats are OK - purrr, apartment, w/d hookups, ...
# 116  [broker fee details: 2595, apartment, laundry ...
# 117  [broker fee details: 2495, apartment, laundry ...
# 118  [broker fee details: 2095, apartment, laundry ...
# 119                              [saturday 2023-01-14]
#
# [120 rows x 9 columns]

# %%
# Exporting data to csv
df.to_csv('boston_data_raw.csv', index=False)
