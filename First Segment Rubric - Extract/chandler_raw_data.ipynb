# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
import numpy as np
import pandas as pd
from time import sleep
from random import randint

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
city = 'Chandler'

# %%
# Set url
url = 'https://phoenix.craigslist.org/search/chandler-az/apa#search=1~thumb~0~0'
browser.visit(url)
sleep(3)

# Parse the HTML
html = browser.html
soup = bs(html, 'html.parser')

# find and extract relevant data
search = soup.find_all('div', class_='result-info')

# Create empty list to store scraped data
datatoget = []

# Loop through data found and extract relevant information
for (counter,link) in enumerate(search):

    # scrape dates
    dates = link.find_all('div', class_='meta')[0].text.split('·')[0]

    # scrape titles
    titles = link.find_all('a', class_='titlestring')[0].text

    # scrape links
    links = link.find_all('a', class_='titlestring', href=True)[0]['href']

    try:
    # scrape prices
        prices = link.find_all('span', class_='priceinfo')[0].text
    except:
        prices = np.nan

    # scrape neighborhoods
    neighborhoods = link.find('div', class_='supertitle').text

    # error handeling in case there are no bedrooms displayed
    try:
        bedrooms = link.find('span', class_='post-bedrooms').text

    except:
        bedrooms = np.nan

    # error handeling in case there are no sqft displayed
    try:
        sqft = link.find('span', class_='post-sqft').text.split()[0][:-3]
    except:
        sqft = np.nan
    
    # visit each link seperately
    browser.visit(links)
    
    # ensures that the server does not get overloaded with requests
    sleep(randint(2,5))  

    # after visiting link, extract bath and amenities data
    html = browser.html
    soup = bs(html, 'html.parser')
    baths = soup.find_all('p', class_='attrgroup')[0].text.split('\n')[1].split()[2][:-2]

    
    amenities = soup.find_all('p', class_='attrgroup')[1].text.split('\n')
    # list comprehension used to make sure no empty strings get added to the list
    all_amenities = [am for am in amenities if am != '']
    
    # print statements to ensure that the correct data is scraped
    print(f'\nListing Number: {counter+1}')
    print(f'Square Footage: {sqft if sqft == sqft else "not available"}')
    print(f'Price: {prices if prices == prices else "not available"}')
    print(f'Title: {titles}')
    print(f'Date: {dates}')
    print(f'Number of Bedrooms: {bedrooms if bedrooms == bedrooms else "not available"}')
    print(f'Neighborhood: {neighborhoods if neighborhoods == neighborhoods else "not available"}')
    print(f'Number of Bathrooms: {baths if baths == baths else "not available"}')
    print(f'Link: {links}')
    print(f'Amenities: {all_amenities}')

    # create dicitonary for our DataFrame
    data = {'date': dates,
            'title': titles,
            'link': links,
            'price': prices,
            'bedroom': bedrooms,
            'sqft': sqft,
            'neighborhood': neighborhoods,
            'bathroom': baths,
            'amenities': all_amenities}
    
    # append the data
    datatoget.append(data)

browser.quit()
# Out:
# Listing Number: 1
# Square Footage: 732
# Price: $1,425
# Title: Picnic area with BBQ grills, Garages Available, Walk-in Closets
# Date: 1/10
# Number of Bedrooms: 1br
# Neighborhood: east valley
# Number of Bathrooms: 1
# Link: https://phoenix.craigslist.org/evl/apa/d/tempe-picnic-area-with-bbq-grills/7575578398.html
# Amenities: ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'carport', 'rent period: monthly']
#
# Listing Number: 2
# Square Footage: 1038
# Price: $1,610
# Title: On-site professional management team
# Date: 1/10
# Number of Bedrooms: 2br
# Neighborhood: east valley
# Number of Bathrooms: 2
# Link: https://phoenix.craigslist.org/evl/apa/d/tempe-on-site-professional-management/7570953216.html
# Amenities: ['apartment', 'w/d in unit', 'detached garage', 'rent period: monthly']
#
# Listing Number: 3
# Square Footage: 1134
# Price: $1,775
# Title: Luxury 1 & 2 bedroom apartments! 50% off 1st 3 months! Call now!
# Date: 1/10
# Number of Bedrooms: 2br
# Neighborhood: 1930 S 24th St, Phoenix, AZ
# Number of Bathrooms: 2
# Link: https://phoenix.craigslist.org/evl/apa/d/mesa-luxury-bedroom-apartments-50-off/7577200198.html
# Amenities: ['open house dates', 'wednesday 2023-01-11', 'thursday 2023-01-12', 'friday 2023-01-13']
#
# Listing Number: 4
# Square Footage: 996
# Price: $1,648
# Title: 2 bedroom, Private balcony or patio, Located in Phoenix
# Date: 1/10
# Number of Bedrooms: 2br
# Neighborhood:
html
# Amenities: ['apartment', 'w/d in unit', 'carport', 'rent period: monthly']
#
# Listing Number: 120
# Square Footage: 1121
# Price: $1,879
# Title: Gorgeous 2 bedroom 2 bathroom w/GREAT amaenities Located in Chandler
# Date: 1/10
# Number of Bedrooms: 2br
# Neighborhood: east valley
# Number of Bathrooms: 2
# Link: https://phoenix.craigslist.org/evl/apa/d/chandler-gorgeous-bedroom-bathroom/7570098603.html
# Amenities: ['apartment', 'w/d in unit', 'carport', 'rent period: monthly']

# %%
datatoget
# Out:
# [{'date': '1/10',
#   'title': 'Picnic area with BBQ grills, Garages Available, Walk-in Closets',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-picnic-area-with-bbq-grills/7575578398.html',
#   'price': '$1,425',
#   'bedroom': '1br',
#   'sqft': '732',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'On-site professional management team',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-on-site-professional-management/7570953216.html',
#   'price': '$1,610',
#   'bedroom': '2br',
#   'sqft': '1038',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Luxury 1 & 2 bedroom apartments! 50% off 1st 3 months! Call now!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-luxury-bedroom-apartments-50-off/7577200198.html',
#   'price': '$1,775',
#   'bedroom': '2br',
#   'sqft': '1134',
#   'neighborhood': '1930 S 24th St, Phoenix, AZ',
#   'bathroom': '2',
#   'amenities': ['open house dates',
#    'wednesday 2023-01-11',
#    'thursday 2023-01-12',
#    'friday 2023-01-13']},
#  {'date': '1/10',
#   'title': '2 bedroom, Private balcony or patio, Located in Phoenix',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/phoenix-bedroom-private-balcony-or/7575035817.html',
#   'price': '$1,648',
#   'bedroom': '2br',
#   'sqft': '996',
#   'neighborhood': '13625 South 48th Street, Phoenix, AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '1/bd 1/ba, Lush landscaped grounds',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bd-ba-lush-landscaped-grounds/7572257620.html',
#   'price': '$1,395',
#   'bedroom': '1br',
#   'sqft': '695',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Washer & Dryer, Detached Garage, Upgraded Interior',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/tempe-washer-dryer-detached-garage/7570273780.html',
#   'price': '$1,446',
#   'bedroom': '2br',
#   'sqft': '811',
#   'neighborhood': 'west valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '3 BD, Basketball court',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-bd-basketball-court/7573670732.html',
#   'price': '$2,273',
#   'bedroom': '3br',
#   'sqft': '1320',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '2 bedroom, Built-in linen closet',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/phoenix-bedroom-built-in-linen-closet/7575647681.html',
#   'price': '$1,554',
#   'bedroom': '2br',
#   'sqft': '1003',
#   'neighborhood': 'west valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Amazing luxury! 1 & 2 bedrooms - 50% off for 2 months! Call now!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-amazing-luxury-bedrooms-50-off-for/7577191012.html',
#   'price': '$1,925',
#   'bedroom': '2br',
#   'sqft': '1134',
#   'neighborhood': '1930 S 24th St, Phoenix, AZ',
#   'bathroom': '2',
#   'amenities': ['open house dates',
#    'wednesday 2023-01-11',
#    'thursday 2023-01-12',
#    'friday 2023-01-13']},
#  {'date': '1/10',
#   'title': 'Interior Unit Upgrades, Basketball Court, On-Call Maintenance',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-interior-unit-upgrades-basketball/7575579999.html',
#   'price': '$1,755',
#   'bedroom': '2br',
#   'sqft': '1167',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Fully Appointed Kitchens, Clubhouse, Free Weights',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-fully-appointed-kitchens-clubhouse/7572969355.html',
#   'price': '$1,550',
#   'bedroom': '2br',
#   'sqft': '1009',
#   'neighborhood': '843 South Longmore Street, Mesa, AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '2/BD, Oversized walk-in closets, in Chandler AZ',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bd-oversized-walk-in-closets-in/7570780229.html',
#   'price': '$1,648',
#   'bedroom': '2br',
#   'sqft': '980',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Flexible lease terms available',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/phoenix-flexible-lease-terms-available/7575022106.html',
#   'price': '$1,403',
#   'bedroom': '1br',
#   'sqft': '732',
#   'neighborhood': '13625 South 48th Street, Phoenix, AZ',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'High Vaulted Ceilings In Your New Beautiful 3 Bedroom Apartment Home',
#   'link': 'https://phoenix.craigslist.org/cph/apa/d/phoenix-high-vaulted-ceilings-in-your/7573677669.html',
#   'price': '$1,970',
#   'bedroom': '3br',
#   'sqft': '1200',
#   'neighborhood': '15815 S Lakewood Pkwy W',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'application fee details: Application Fee: $50 (Anyone applying that is 18 or older).',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Online Payments Available, On-Call Maintenance, Faux Wood Flooring',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-online-payments-available-on-call/7575578939.html',
#   'price': '$1,605',
#   'bedroom': '2br',
#   'sqft': '983',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '2BD 2BA, In-home washer and dryer, In Tempe',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/tempe-2bd-2ba-in-home-washer-and-dryer/7574051538.html',
#   'price': '$1,362',
#   'bedroom': '2br',
#   'sqft': '811',
#   'neighborhood': 'west valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '2B/2B, Private balcony or patio',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/phoenix-2b-2b-private-balcony-or-patio/7574212367.html',
#   'price': '$1,648',
#   'bedroom': '2br',
#   'sqft': '996',
#   'neighborhood': '13625 South 48th Street, Phoenix, AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '2/bd 2/ba, BBQ/picnic area',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bd-ba-bbq-picnic-area/7576247338.html',
#   'price': '$1,566',
#   'bedroom': '2br',
#   'sqft': '980',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '1 Bedroom 1 Bath',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-bedroom-bath/7576366488.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'Clean Single Level Family Home!3 Bed/2 Bath! Immediate Move In!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/gilbert-clean-single-level-family-home3/7568726906.html',
#   'price': '$2,250',
#   'bedroom': '3br',
#   'sqft': '1650',
#   'neighborhood': 'Gilbert, chandler, east valley',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'house',
#    'w/d hookups',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Walk-in Closets, Fireplace, Basketball Court',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-walk-in-closets-fireplace/7577156529.html',
#   'price': '$1,605',
#   'bedroom': '2br',
#   'sqft': '983',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Pet friendly (breed restrictions apply)',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/tempe-pet-friendly-breed-restrictions/7567443745.html',
#   'price': '$1,749',
#   'bedroom': '2br',
#   'sqft': '1038',
#   'neighborhood': 'west valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '1 Bedroom 1 Bath Apartment -No Leases',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-bedroom-bath-apartment-no-leases/7573859465.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'Garages Available, Dog Park with Agility Equipment, Walk-in Closets',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-garages-available-dog-park-with/7577156930.html',
#   'price': '$1,710',
#   'bedroom': '2br',
#   'sqft': '1040',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '3/bd 2/ba, Spacious pantries, Chandler AZ',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-bd-ba-spacious-pantries/7574986044.html',
#   'price': '$2,190',
#   'bedroom': '3br',
#   'sqft': '1320',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '3/bd 2/ba, Subway tile kitchen backsplash, Phoenix AZ',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/phoenix-bd-ba-subway-tile-kitchen/7575691918.html',
#   'price': '$1,802',
#   'bedroom': '3br',
#   'sqft': '1204',
#   'neighborhood': 'west valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '1 Bedroom 1 Bath',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-bedroom-bath/7576363373.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'Furnished Apartments',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-furnished-apartments/7577143948.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'Separate Dining Area, Air Conditioner, On-line Resident Services',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-separate-dining-area-air/7575696143.html',
#   'price': '$1,590',
#   'bedroom': '2br',
#   'sqft': '1009',
#   'neighborhood': '843 South Longmore Street, Mesa, AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Clubhouse with Free Wi-Fi, On-Call Maintenance, Fireplace',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-clubhouse-with-free-wi-fi-on-call/7575579369.html',
#   'price': '$1,710',
#   'bedroom': '2br',
#   'sqft': '1040',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Integrated Desk and Display Niche *, Private Balcony',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-integrated-desk-and-display-niche/7577159980.html',
#   'price': '$1,814',
#   'bedroom': '1br',
#   'sqft': '779',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'immediate move-in / washer and Dryer',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-immediate-move-in-washer-and/7573283616.html',
#   'price': '$1,759',
#   'bedroom': '3br',
#   'sqft': '1232',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Garages & Carport Parking Available, Custom Cabinetry, Open Floor',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/gilbert-garages-carport-parking/7577158430.html',
#   'price': '$1,708',
#   'bedroom': '2br',
#   'sqft': '1150',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Furnished Apartments',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-furnished-apartments/7576366234.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'Elevate at Discovery park beatiful apartments',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-elevate-at-discovery-park/7575532620.html',
#   'price': '$1,435',
#   'bedroom': '2br',
#   'sqft': '811',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Dedicated covered parking available',
#   'link': 'https://phoenix.craigslist.org/cph/apa/d/chandler-dedicated-covered-parking/7576377379.html',
#   'price': '$1,579',
#   'bedroom': '3br',
#   'sqft': '1232',
#   'neighborhood': '2150 S Arizona Ave, Phoenix, AZ',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Furnished Apartments',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-furnished-apartments/7576362668.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'Garages Available, Basketball Court, Online Payments Available',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-garages-available-basketball/7577149710.html',
#   'price': '$1,425',
#   'bedroom': '1br',
#   'sqft': '732',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Apartment Alternative',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-apartment-alternative/7577144230.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': '1 Bedroom Apartment -No Leases',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-bedroom-apartment-no-leases/7577135722.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': '1 bedroom, Courtyard, Located in Chandler',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bedroom-courtyard-located-in/7572981707.html',
#   'price': '$1,395',
#   'bedroom': '1br',
#   'sqft': '695',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '1/BD 1/BA, Furnished apartments available',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-bd-ba-furnished-apartments/7575595177.html',
#   'price': '$1,465',
#   'bedroom': '1br',
#   'sqft': '740',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Furnished Apartments',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-furnished-apartments/7576370550.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'We Are Waiting For You! Stop In For A Tour Today!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/phoenix-we-are-waiting-for-you-stop-in/7577154331.html',
#   'price': '$1,716',
#   'bedroom': '1br',
#   'sqft': '920',
#   'neighborhood': 'Phoenix',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Apartment living with out a Lease!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-apartment-living-with-out-lease/7577143431.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': '825 S DOBSON RD MESA',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'Gorgeous 1198 Sq Ft, 3 Bed / 2 Bath near public transportation',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-gorgeous-1198-sq-ft-bed-bath/7577153260.html',
#   'price': '$2,140',
#   'bedroom': '3br',
#   'sqft': '1198',
#   'neighborhood': 'Chandler',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '1/bd, Sand volleyball court',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/phoenix-bd-sand-volleyball-court/7575694391.html',
#   'price': '$1,440',
#   'bedroom': '1br',
#   'sqft': '732',
#   'neighborhood': 'west valley',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': "Don't Want To Be in A Lease",
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-dont-want-to-be-in-lease/7576365607.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'ONE BEDROOM - ALL UTILITIES PAID',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-one-bedroom-all-utilities-paid/7577144525.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': '1 Bedroom Apartment -No Leases',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-bedroom-apartment-no-leases/7577140030.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': '1BD 1BA, Kitchen breakfast bar',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-1bd-1ba-kitchen-breakfast-bar/7573282907.html',
#   'price': '$1,443',
#   'bedroom': '1br',
#   'sqft': '681',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '1 Bedroom Apartment -No Leases',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-bedroom-apartment-no-leases/7577143706.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'Refrigerator with Ice Maker, Sand Volleyball Courts, Package Concierge',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/phoenix-refrigerator-with-ice-maker/7577144715.html',
#   'price': '$1,659',
#   'bedroom': '2br',
#   'sqft': '1053',
#   'neighborhood': 'Ahwatukee',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Cyber Café, Wood Vinyl Flooring, Spa, Disposal',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-cyber-caf-wood-vinyl-flooring/7577142988.html',
#   'price': '$1,449',
#   'bedroom': '1br',
#   'sqft': '638',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Current special!!! $500 Off total Move in & $99 Admin Fee',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-current-special-500-off-total-move/7577145604.html',
#   'price': '$1,253',
#   'bedroom': nan,
#   'sqft': '380',
#   'neighborhood': 'Dobson Ranch',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Ask About Move in Specials, Tour Today, A Must See, Pantry',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/gilbert-ask-about-move-in-specials-tour/7577145502.html',
#   'price': '$1,375',
#   'bedroom': '1br',
#   'sqft': '605',
#   'neighborhood': "Downtown Gilbert, Near Sam's Club",
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Tour Today, 24 Hour Emergency Maintenance, Controlled Access',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-tour-today-24-hour-emergency/7577145385.html',
#   'price': '$1,510',
#   'bedroom': '2br',
#   'sqft': '961',
#   'neighborhood': 'Mesa',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Air Conditioner, Spa/Hot Tub, Washer/Dryer, Electronic Thermostat',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-air-conditioner-spa-hot-tub/7577145185.html',
#   'price': '$2,772',
#   'bedroom': '3br',
#   'sqft': '1217',
#   'neighborhood': 'Tempe, AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Playground, Poolside Cabanas, Spanish Speaking Staff',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-playground-poolside-cabanas/7577145104.html',
#   'price': '$2,096',
#   'bedroom': '2br',
#   'sqft': '1046',
#   'neighborhood': 'Attached Garages and Detached Garages',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Walk In closets, Air Conditioning, Copy/Fax/Scan Available',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-walk-in-closets-air-conditioning/7577145001.html',
#   'price': '$1,518',
#   'bedroom': '1br',
#   'sqft': '794',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Short Term Lease, Courtesy Patrol, Washer/Dryer',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-short-term-lease-courtesy/7577144880.html',
#   'price': '$2,035',
#   'bedroom': '3br',
#   'sqft': '1182',
#   'neighborhood': 'Chandler',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '1/bd, Oversized walk-in closets',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bd-oversized-walk-in-closets/7572368369.html',
#   'price': '$1,597',
#   'bedroom': '1br',
#   'sqft': '940',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Resident BBQ Area, Concierge Services, Pet Exercise Park',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-resident-bbq-area-concierge/7577144695.html',
#   'price': '$1,350',
#   'bedroom': '2br',
#   'sqft': '900',
#   'neighborhood': 'Dobson Ranch',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Two Heated Pools, Off-street parking, Granite Countertops',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-two-heated-pools-off-street/7577144465.html',
#   'price': '$2,400',
#   'bedroom': '3br',
#   'sqft': '1244',
#   'neighborhood': 'San Marcos',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Ceiling Fans, Horseshoe Pits, Large Balconies or Patios',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-ceiling-fans-horseshoe-pits-large/7577144381.html',
#   'price': '$1,975',
#   'bedroom': '3br',
#   'sqft': '1194',
#   'neighborhood': 'Gilbert',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'New Modern Lighting*, Major Employer Discounts Offered',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-new-modern-lighting-major/7577144372.html',
#   'price': '$1,826',
#   'bedroom': '2br',
#   'sqft': '970',
#   'neighborhood': 'Chandler',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'State-of-the-Art Fitness Center, Package Lockers, Faux Wood Flooring',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-state-of-the-art-fitness-center/7575606554.html',
#   'price': '$1,605',
#   'bedroom': '2br',
#   'sqft': '983',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Garages Available, Large Closets, Limited Access Gates',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-garages-available-large-closets/7577144157.html',
#   'price': '$1,923',
#   'bedroom': '2br',
#   'sqft': '1112',
#   'neighborhood': 'Chandler',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Fitness Center, Centralized Heating & Cooling, Package Receiving',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-fitness-center-centralized-heating/7577144013.html',
#   'price': '$1,990',
#   'bedroom': '3br',
#   'sqft': '1152',
#   'neighborhood': 'Mesa',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Gated Community Access, Ample Storage Space, Covered Parking',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-gated-community-access-ample/7577143907.html',
#   'price': '$1,295',
#   'bedroom': '1br',
#   'sqft': '701',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '1B/1B, Gilbert School District, In Chandler',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-1b-1b-gilbert-school-district/7570741108.html',
#   'price': '$1,339',
#   'bedroom': '1br',
#   'sqft': '792',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Come home to gorgeous waterfront views every day! Tour today!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-come-home-to-gorgeous/7577143678.html',
#   'price': '$1,664',
#   'bedroom': '2br',
#   'sqft': '878',
#   'neighborhood': '1586 W Maggio Way, Chandler AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'application fee details: $50',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Dog and Cat-Friendly 657 SqFt 1 Bed / 1 Bath! Pets Welcome Here!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-dog-and-cat-friendly-657-sqft/7577143613.html',
#   'price': '$1,362',
#   'bedroom': '1br',
#   'sqft': '657',
#   'neighborhood': '1586 W Maggio Way, Chandler AZ',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'application fee details: $50',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Spa/Hot Tub, Patio/Balcony, Business Center',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-spa-hot-tub-patio-balcony-business/7577143346.html',
#   'price': '$1,372',
#   'bedroom': '1br',
#   'sqft': '660',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Oversized Soaking Tub with Ceramic Tile Surround, Controlled Access',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-oversized-soaking-tub-with/7577143287.html',
#   'price': '$2,192',
#   'bedroom': '2br',
#   'sqft': '1134',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Reserve Your New Home Today & Receive an Incredible Move-in Special!*',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/gilbert-reserve-your-new-home-today/7577143108.html',
#   'price': '$1,615',
#   'bedroom': '1br',
#   'sqft': '674',
#   'neighborhood': 'A Cultivated Community',
#   'bathroom': '1',
#   'amenities': ['EV charging',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Playground, Large Bedrooms, Covered Parking, Balcony or Patio',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/gilbert-playground-large-bedrooms/7577142870.html',
#   'price': '$1,831',
#   'bedroom': '2br',
#   'sqft': '1085',
#   'neighborhood': 'Near Power Ranch',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Bark Park, Central Heating & Air Conditioning, Vaulted Ceilings',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bark-park-central-heating-air/7577142728.html',
#   'price': '$1,599',
#   'bedroom': '2br',
#   'sqft': '1102',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'ONE BEDROOM APTS - NO CREDIT CHECKS',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-one-bedroom-apts-no-credit-checks/7576362416.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': "Look No Further! We've Got What You Need @ The Cooper 202!",
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-look-no-further-weve-got-what/7577142465.html',
#   'price': '$1,633',
#   'bedroom': '1br',
#   'sqft': '737',
#   'neighborhood': 'Chandler',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Conveniently Located Near Major Freeways and Chandler Fashion Mall',
#   'link': 'https://phoenix.craigslist.org/cph/apa/d/chandler-conveniently-located-near/7577142437.html',
#   'price': '$1,750',
#   'bedroom': '2br',
#   'sqft': '1022',
#   'neighborhood': 'Chandler',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Two Resort Pools - One Heated, Washer/Dryer, Wood Style Flooring',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-two-resort-pools-one-heated-washer/7574960833.html',
#   'price': '$1,550',
#   'bedroom': '2br',
#   'sqft': '1009',
#   'neighborhood': '843 South Longmore Street, Mesa, AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Dishwasher, Easy Freeway Access, Undermounted Sinks*',
#   'link': 'https://phoenix.craigslist.org/cph/apa/d/mesa-dishwasher-easy-freeway-access/7577142429.html',
#   'price': '$1,400',
#   'bedroom': '2br',
#   'sqft': '725',
#   'neighborhood': 'Tempe, AZ',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'APARTMENT OPTIONS - FREE RENTAL SERVICE! WE MAKE IT EASY!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/apartment-options-free-rental-service/7574989072.html',
#   'price': '$1,695',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'East Valley - Mesa, Tempe, East Phoenix, South Scottsdale',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '1 Bedroom Apartment -No Leases',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-bedroom-apartment-no-leases/7576363094.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: weekly']},
#  {'date': '1/10',
#   'title': 'LOOKING TO RENT?  We Can Help! Free Rental Service: Apartment Options',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/looking-to-rent-we-can-help-free-rental/7574989188.html',
#   'price': '$1,525',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'East Valley: Mesa, Tempe, South Scottsdale, Chandler',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'HAPPY HOLIDAYS FROM APARTMENT OPTIONS: Free Rental Service! EVERYDAY!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/happy-holidays-from-apartment-options/7571324978.html',
#   'price': '$1,950',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'East Valley: Mesa, Tempe, Chandler, Gilbert, Scottsdale',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'SAVE TIME, MONEY & ENERGY - FREE APPROVAL - NEVER A FEE HERE:)',
#   'link': 'https://phoenix.craigslist.org/cph/apa/d/mesa-save-time-money-energy-free/7574241434.html',
#   'price': '$1,750',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'SCOTTSDALE/TEMPE/MESA/AHWATUKEE',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Looking To Rent A Great Apartment? - We Can Help! Call Now!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/looking-to-rent-great-apartment-we-can/7573352823.html',
#   'price': '$1,699',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'East Valley - MESA & GILBERT',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Professional On-site Management, Upgraded Fully Stacked Kitchens*',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/gilbert-professional-on-site-management/7577142090.html',
#   'price': '$1,350',
#   'bedroom': '1br',
#   'sqft': '572',
#   'neighborhood': 'Downtown Gilbert',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '24-Hour Resident Maintenance Staff, Walk-in Closets, Pool and Spa',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-24-hour-resident-maintenance/7577142016.html',
#   'price': '$1,350',
#   'bedroom': '1br',
#   'sqft': '600',
#   'neighborhood': 'Chandler, Arizona',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'ALL UTILITIES INCLUDED - ONE BEDROOMS',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-all-utilities-included-one-bedrooms/7576365921.html',
#   'price': '$389',
#   'bedroom': '1br',
#   'sqft': '395',
#   'neighborhood': 'Mesa',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'furnished',
#    'apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: weekly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Rental in Gilbert with Right to Purchase',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/gilbert-rental-in-gilbert-with-right-to/7577134016.html',
#   'price': '$2,600',
#   'bedroom': '3br',
#   'sqft': '1323',
#   'neighborhood': 'Gilbert',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'application fee details: $75 for the entire household',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'house',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '2bd 2ba, White shaker cabinetry',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/phoenix-2bd-2ba-white-shaker-cabinetry/7574191673.html',
#   'price': '$1,651',
#   'bedroom': '2br',
#   'sqft': '1003',
#   'neighborhood': '13625 South 48th Street, Phoenix, AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Spacious 1 Bedroom Renovated Apartment Home',
#   'link': 'https://phoenix.craigslist.org/cph/apa/d/phoenix-spacious-bedroom-renovated/7575687737.html',
#   'price': '$1,739',
#   'bedroom': '1br',
#   'sqft': '800',
#   'neighborhood': '15815 S Lakewood Pkwy W',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'application fee details: Application Fee: $50 (Anyone applying that is 18 or older).',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Spacious and extensively upgraded 2 bed, 2 bath in Mesa',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-spacious-and-extensively-upgraded/7577137059.html',
#   'price': '$1,278',
#   'bedroom': '2br',
#   'sqft': '1100',
#   'neighborhood': 'Mesa',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'detached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'Refrigerator, BBQ/Picnic Area, Clubhouse, Fitness Center',
#   'link': 'https://phoenix.craigslist.org/cph/apa/d/tempe-refrigerator-bbq-picnic-area/7577136798.html',
#   'price': '$1,585',
#   'bedroom': '2br',
#   'sqft': '825',
#   'neighborhood': 'Chandler',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '$399 Total Move In Special on Two Bedrooms!!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-399-total-move-in-special-on-two/7577136381.html',
#   'price': '$1,445',
#   'bedroom': '2br',
#   'sqft': '800',
#   'neighborhood': 'Tempe',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'no parking',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '2 Bed, Flexible lease terms available, Situated in Tempe!',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/tempe-bed-flexible-lease-terms/7576255137.html',
#   'price': '$1,518',
#   'bedroom': '2br',
#   'sqft': '939',
#   'neighborhood': 'west valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'A home for everyone - even your pets! Pet friendly 3 bed / 2 bath!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-home-for-everyone-even-your/7577134212.html',
#   'price': '$2,260',
#   'bedroom': '3br',
#   'sqft': '1074',
#   'neighborhood': 'Chandler',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'application fee details: $50',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Why live anywhere else when you can live at Avenue 8?',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-why-live-anywhere-else-when-you/7577133751.html',
#   'price': '$1,278',
#   'bedroom': '2br',
#   'sqft': '1100',
#   'neighborhood': 'Mesa',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'detached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '2 Bed, Gilbert School District',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-bed-gilbert-school-district/7576338894.html',
#   'price': '$1,687',
#   'bedroom': '2br',
#   'sqft': '960',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Contemporary Cabinetry, Cox Quick Connect Modems, Built-In Microwaves',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-contemporary-cabinetry-cox/7577133477.html',
#   'price': '$1,734',
#   'bedroom': '2br',
#   'sqft': '960',
#   'neighborhood': 'Chandler - Ocotillo',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '1/bd, BBQ/picnic area',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bd-bbq-picnic-area/7573244945.html',
#   'price': '$1,395',
#   'bedroom': '1br',
#   'sqft': '695',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '2 Sparkling Swimming Pools & Hot Tub, Basketball Court, Ceiling fan',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-sparkling-swimming-pools-hot-tub/7575995787.html',
#   'price': '$1,425',
#   'bedroom': '1br',
#   'sqft': '732',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '-4 Bed 2 Bath House In Central Mesa-Fenced Yard & RV Gate-',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-bed-bath-house-in-central-mesa/7575019045.html',
#   'price': '$3,095',
#   'bedroom': '4br',
#   'sqft': '1750',
#   'neighborhood': '321 E 7th Dr.',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'house',
#    'w/d hookups',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': "Don't Let Credit Issues Get In The Way Of Finding Your New Place!!",
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/dont-let-credit-issues-get-in-the-way/7576106434.html',
#   'price': '$1,695',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'East Valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'APPROVAL HASSLE FREE - PERFECT CREDIT NOT REQUIRED - PET FRIENDLY',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-approval-hassle-free-perfect/7574591805.html',
#   'price': '$2,250',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Mesa - Tempe - Chandler - Ahwatukee - Gilbert',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '*Price or Quality you DECIDE  - Free Rental Service - We Make It Easy!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-price-or-quality-you-decide-free/7569372528.html',
#   'price': '$1,695',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'East Valley - Chandler/Tempe/Mesa/Ahwatukee',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': 'APPROVAL HASSLE FREE - PERFECT CREDIT NOT REQUIRED - PET FRIENDLY',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-approval-hassle-free-perfect/7577130509.html',
#   'price': '$2,195',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Mesa - Tempe - Chandler - Ahwatukee - Gilbert',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '1/BD 1/BA, 9-foot ceilings',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-bd-ba-foot-ceilings/7575687414.html',
#   'price': '$1,427',
#   'bedroom': '1br',
#   'sqft': '681',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Ideal location! Close to everything! 1 bed / 1 bath! 466 Sqft!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/gilbert-ideal-location-close-to/7577129749.html',
#   'price': '$1,230',
#   'bedroom': '1br',
#   'sqft': '466',
#   'neighborhood': 'Gilbert - Phoenix-Mesa Gateway Airport',
#   'bathroom': '1',
#   'amenities': ['application fee details: $60',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '2bd 2ba, Oversized walk-in closets',
#   'link': 'https://phoenix.craigslist.org/wvl/apa/d/phoenix-2bd-2ba-oversized-walk-in/7576335254.html',
#   'price': '$1,651',
#   'bedroom': '2br',
#   'sqft': '1003',
#   'neighborhood': '13625 South 48th Street, Phoenix, AZ',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '3/bd, Furnished apartments available, In Chandler',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bd-furnished-apartments-available/7577125485.html',
#   'price': '$1,808',
#   'bedroom': '3br',
#   'sqft': '1195',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Cable Ready, Great Neighborhood, Professional Management',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/mesa-cable-ready-great-neighborhood/7577124837.html',
#   'price': '$1,645',
#   'bedroom': '2br',
#   'sqft': '982',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Elevate at Discovery park beatiful apartments',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-elevate-at-discovery-park/7575533318.html',
#   'price': '$1,570',
#   'bedroom': '2br',
#   'sqft': '1152',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': '3 BED 2 BATH Available NOW!! 1180 sq ft',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-bed-bath-available-now-1180-sq-ft/7577122633.html',
#   'price': '$1,924',
#   'bedroom': '3br',
#   'sqft': '1180',
#   'neighborhood': 'Tempe',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Conventional Kitchen, Resident BBQ Area, Reserved Covered Parking',
#   'link': 'https://phoenix.craigslist.org/cph/apa/d/phoenix-conventional-kitchen-resident/7577122222.html',
#   'price': '$1,899',
#   'bedroom': '2br',
#   'sqft': '1260',
#   'neighborhood': 'Phoenix',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': '1/10',
#   'title': '1bd 1ba, Air conditioner, Situated in Chandler!',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/tempe-1bd-1ba-air-conditioner-situated/7567931058.html',
#   'price': '$1,436',
#   'bedroom': '1br',
#   'sqft': '720',
#   'neighborhood': 'east valley',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': '1/10',
#   'title': 'Gorgeous 2 bedroom 2 bathroom w/GREAT amaenities Located in Chandler',
#   'link': 'https://phoenix.craigslist.org/evl/apa/d/chandler-gorgeous-bedroom-bathroom/7570098603.html',
#   'price': '$1,879',
#   'bedroom': '2br',
#   'sqft': '1121',
#   'neighborhood': 'east valley',
#   'bathroom': '2',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']}]

# %%
# creating DataFrame
df = pd.DataFrame(datatoget)
df
# Out:
#      date                                              title  \
# 0    1/10  Picnic area with BBQ grills, Garages Available...
# 1    1/10               On-site professional management team
# 2    1/10  Luxury 1 & 2 bedroom apartments! 50% off 1st 3...
# 3    1/10  2 bedroom, Private balcony or patio, Located i...
# 4    1/10                 1/bd 1/ba, Lush landscaped grounds
# ..    ...                                                ...
# 115  1/10      Elevate at Discovery park beatiful apartments
# 116  1/10            3 BED 2 BATH Available NOW!! 1180 sq ft
# 117  1/10  Conventional Kitchen, Resident BBQ Area, Reser...
# 118  1/10    1bd 1ba, Air conditioner, Situated in Chandler!
# 119  1/10  Gorgeous 2 bedroom 2 bathroom w/GREAT amaeniti...
#
#                                                   link   price bedroom  sqft  \
# 0    https://phoenix.craigslist.org/evl/apa/d/tempe...  $1,425     1br   732
# 1    https://phoenix.craigslist.org/evl/apa/d/tempe...  $1,610     2br  1038
# 2    https://phoenix.craigslist.org/evl/apa/d/mesa-...  $1,775     2br  1134
# 3    https://phoenix.craigslist.org/wvl/apa/d/phoen...  $1,648     2br   996
# 4    https://phoenix.craigslist.org/evl/apa/d/tempe...  $1,395     1br   695
# ..                                                 ...     ...     ...   ...
# 115  https://phoenix.craigslist.org/evl/apa/d/tempe...  $1,570     2br  1152
# 116  https://phoenix.craigslist.org/evl/apa/d/tempe...  $1,924     3br  1180
# 117  https://phoenix.craigslist.org/cph/apa/d/phoen...  $1,899     2br  1260
# 118  https://phoenix.craigslist.org/evl/apa/d/tempe...  $1,436     1br   720
# 119  https://phoenix.craigslist.org/evl/apa/d/chand...  $1,879     2br  1121
#
#                              neighborhood bathroom  \
# 0                             east valley        1
# 1                             east valley        2
# 2             1930 S 24th St, Phoenix, AZ        2
# 3    13625 South 48th Street, Phoenix, AZ        2
# 4                             east valley        1
# ..                                    ...      ...
# 115                           east valley        2
# 116                                 Tempe        2
# 117                               Phoenix        2
# 118                           east valley        1
# 119                           east valley        2
#
#                                              amenities
# 0    [cats are OK - purrr, dogs are OK - wooof, apa...
# 1    [apartment, w/d in unit, detached garage, rent...
# 2    [open house dates, wednesday 2023-01-11, thurs...
# 3    [air conditioning, cats are OK - purrr, dogs a...
# 4    [apartment, w/d in unit, carport, rent period:...
# ..                                                 ...
# 115  [apartment, w/d in unit, detached garage, rent...
# 116  [air conditioning, cats are OK - purrr, dogs a...
# 117  [cats are OK - purrr, dogs are OK - wooof, apa...
# 118  [apartment, w/d in unit, carport, rent period:...
# 119  [apartment, w/d in unit, carport, rent period:...
#
# [120 rows x 9 columns]

# %%
# Exporting data to csv
df.to_csv(f"{city}_data_raw.csv", index=False)
