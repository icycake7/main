# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
import numpy as np
import pandas as pd
from time import sleep
from random import randint

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
city = 'Chicago'

# %%
# Set url
url = 'https://chicago.craigslist.org/search/apa'
browser.visit(url)
sleep(3)

# Parse the HTML
html = browser.html
soup = bs(html, 'html.parser')

# find and extract relevant data
search = soup.find_all('div', class_='result-info')

# Create empty list to store scraped data
datatoget = []

# Loop through data found and extract relevant information
for (counter,link) in enumerate(search):

#     if counter == 15:
#         break
    # scrape dates
    dates = link.find_all('time', class_='result-date')[0].text.split('·')[0]

    # scrape titles
    titles = link.find_all('a', class_='result-title hdrlnk')[0].text

    # scrape links
    links = link.find_all('a', class_='result-title hdrlnk', href=True)[0]['href']

    try:
    # scrape prices
        prices = link.find_all('span', class_='result-price')[0].text
    except:
        prices = np.nan

    # scrape neighborhoods
    try:
        neighborhoods = link.find('span', class_='result-hood').text.strip()[1:-1]

    except:
        neighborhoods = np.nan
    
    # visit each link seperately
    browser.visit(links)
    
    # ensures that the server does not get overloaded with requests
    sleep(randint(2,5))  

    # after visiting link, extract bath and amenities data
    html = browser.html
    soup = bs(html, 'html.parser')
    baths = soup.find_all('p', class_='attrgroup')[0].text.split('\n')[1].split()[2][:-2]

    try:
        if soup.find_all('p', class_='attrgroup')[0].text.split('\n')[2][-3:] == 'ft2':
            sqft = soup.find_all('p', class_='attrgroup')[0].text.split('\n')[2][:-3]
        else:
            sqft = np.nan
    except:
        sqft = np.nan    
    
    
    # error handeling in case there are no bedrooms displayed
    try:
        bedrooms = soup.find_all('p', class_='attrgroup')[0].text.split('\n')[1].split('/')[0].strip().lower()

    except:
        bedrooms = np.nan
    
    amenities = soup.find_all('p', class_='attrgroup')[1].text.split('\n')
    # list comprehension used to make sure no empty strings get added to the list
    all_amenities = [am for am in amenities if am != '']
    
    # print statements to ensure that the correct data is scraped
    print(f'\nListing Number: {counter+1}')
    print(f'Square Footage: {sqft if sqft == sqft else "not available"}')
    print(f'Price: {prices if prices == prices else "not available"}')
    print(f'Title: {titles}')
    print(f'Date: {dates}')
    print(f'Number of Bedrooms: {bedrooms if bedrooms == bedrooms else "not available"}')
    print(f'Neighborhood: {neighborhoods if neighborhoods == neighborhoods else "not available"}')
    print(f'Number of Bathrooms: {baths if baths == baths else "not available"}')
    print(f'Link: {links}')
    print(f'Amenities: {all_amenities}')

    # create dicitonary for our DataFrame
    data = {'date': dates,
            'title': titles,
            'link': links,
            'price': prices,
            'bedroom': bedrooms,
            'sqft': sqft,
            'neighborhood': neighborhoods,
            'bathroom': baths,
            'amenities': all_amenities}
    
    # append the data
    datatoget.append(data)

browser.quit()
# Out:
# Listing Number: 1
# Square Footage: 600
# Price: $675
# Title: Brighton Park Studio Apartment for Rent
# Date: Jan 10
# Number of Bedrooms: 0br
# Neighborhood: Brighton Park Chicago
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/chc/apa/d/chicago-brighton-park-studio-apartment/7577197405.html
# Amenities: ['application fee details: Application fee for background & credit check', 'apartment', 'no laundry on site', 'no smoking', 'street parking', 'rent period: monthly', 'wheelchair accessible']
#
# Listing Number: 2
# Square Footage: 1500
# Price: $1,800
# Title: South Oak Park Apartment
# Date: Jan 10
# Number of Bedrooms: 3br
# Neighborhood: Oak Park
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/nwc/apa/d/oak-park-south-oak-park-apartment/7577194028.html
# Amenities: ['apartment', 'laundry in bldg', 'detached garage', 'rent period: monthly']
#
# Listing Number: 3
# Square Footage: 750
# Price: $925
# Title: 1 Bedroom House Near Griffith
# Date: Jan 10
# Number of Bedrooms: 1br
# Neighborhood:
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/chc/apa/d/chicago-renovated-loft-apartment-with/7576970384.html
# Amenities: ['air conditioning', 'application fee details: $40.00', 'cats are OK - purrr', 'apartment', 'laundry in bldg', 'no smoking', 'off-street parking', 'rent period: monthly']
#
# Listing Number: 113
# Square Footage: 1200
# Price: $1,400
# Title: South Shore Condo with Lake Views
# Date: Jan 10
# Number of Bedrooms: 2br
# Neighborhood: 7337 South Shore Drive Unit1415
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/chc/apa/d/south-shore-condo-with-lake-views/7576969571.html
# Amenities: ['air conditioning', 'application fee details: $40 application fee per adult', 'condo', 'laundry in bldg', 'attached garage', 'rent period: monthly', 'wheelchair accessible']
#
# Listing Number: 114
# Square Footage: not available
# Price: $1,200
# Title: Beautiful Three   Bedroom Units @ Dr. King Legacy Apartments
# Date: Jan 10
# Number of Bedrooms: 3br
# Neighborhood: 1550 S Hamlin ( North Lawndale)
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/chc/apa/d/chicago-beautiful-three-bedroom-units/7576969024.html
# Amenities: ['apartment', 'laundry on site', 'street parking', 'rent period: monthly']
#
# Listing Number: 115
# Square Footage: not available
# Price: $1,430
# Title: **Re-Let**  Beautiful One  Bedroom Units@ Oak Park
# Date: Jan 10
# Number of Bedrooms: 1br
# Neighborhood: Fountainhead Apartments
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/wcl/apa/d/oak-park-re-let-beautiful-one-bedroom/7576968444.html
# Amenities: ['apartment', 'laundry on site', 'street parking', 'rent period: monthly']
#
# Listing Number: 116
# Square Footage: not available
# Price: $1,000
# Title: Location! Heat Included! Hardwood Floors! Small Dog Ok! Ready Now!
# Date: Jan 10
# Number of Bedrooms: 1br
# Neighborhood: Mayfair
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/chc/apa/d/chicago-location-heat-included-hardwood/7576967765.html
# Amenities: ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'street parking', 'rent period: monthly']
# Listing Number: 117
# Square Footage: not available
# Price: $3,300
# Title: LOYOLA BEACH  4 BED 2 BATH  TOP FLOOR
# Date: Jan 10
# Number of Bedrooms: 4br
# Neighborhood: Rogers Park
# Number of Bathrooms: 2
# Link: https://chicago.craigslist.org/chc/apa/d/chicago-loyola-beach-bed-bath-top-floor/7576967700.html
# Amenities: ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'w/d in unit', 'attached garage', 'rent period: monthly']
#
# Listing Number: 118
# Square Footage: 550
# Price: $1,395
# Title: Rare Lincoln Square Jr One bedroom!
# Date: Jan 10
# Number of Bedrooms: 1br
# Neighborhood: Lincoln Square
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/chc/apa/d/chicago-rare-lincoln-square-jr-one/7576966561.html
# Amenities: ['cats are OK - purrr', 'apartment', 'laundry in bldg', 'street parking', 'rent period: monthly']
#
# Listing Number: 119
# Square Footage: not available
# Price: $1,460
# Title: Spacious Apartments -One, Two, Three -Itasca, Il
# Date: Jan 10
# Number of Bedrooms: 2br
# Neighborhood: Colonial Village Apartments -1640 Norwood Ave
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/nwc/apa/d/medinah-spacious-apartments-one-two/7576966382.html
# Amenities: ['cats are OK - purrr', 'dogs are OK - wooof', 'apartment', 'laundry on site', 'street parking', 'rent period: monthly']
#
# Listing Number: 120
# Square Footage: not available
# Price: $1,300
# Title: Beautiful  One  Bedroom Units @ Lotus Garden Apartments - Skokie
# Date: Jan 10
# Number of Bedrooms: 1br
# Neighborhood: 8538 N Lotus - Skokie
# Number of Bathrooms: 1
# Link: https://chicago.craigslist.org/wcl/apa/d/skokie-beautiful-one-bedroom-units/7576965273.html
# Amenities: ['cats are OK - purrr', 'apartment', 'laundry on site', 'off-street parking', 'rent period: monthly']

# %%
datatoget
# Out:
# [{'date': 'Jan 10',
#   'title': 'Brighton Park Studio Apartment for Rent',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-brighton-park-studio-apartment/7577197405.html',
#   'price': '$675',
#   'bedroom': '0br',
#   'sqft': '600',
#   'neighborhood': 'Brighton Park Chicago',
#   'bathroom': '1',
#   'amenities': ['application fee details: Application fee for background & credit check',
#    'apartment',
#    'no laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': 'Jan 10',
#   'title': 'South Oak Park Apartment',
#   'link': 'https://chicago.craigslist.org/nwc/apa/d/oak-park-south-oak-park-apartment/7577194028.html',
#   'price': '$1,800',
#   'bedroom': '3br',
#   'sqft': '1500',
#   'neighborhood': 'Oak Park',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '1 Bedroom House Near Griffith',
#   'link': 'https://chicago.craigslist.org/nwi/apa/d/gary-bedroom-house-near-griffith/7577192992.html',
#   'price': '$925',
#   'bedroom': '1br',
#   'sqft': '750',
#   'neighborhood': 'Griffith/Calumet Township',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'house',
#    'w/d hookups',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'GORGEOUS 1 Bedroom in West Loop! W/D in Unit, Gym, Pool plus more!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-gorgeous-bedroom-in-west-loop-d/7577192861.html',
#   'price': '$2,260',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'West Loop',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'All new renovation! Ample natural light!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-all-new-renovation-ample/7577191039.html',
#   'price': '$1,050',
#   'bedroom': '0br',
#   'sqft': '500',
#   'neighborhood': 'Lakeview',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Medical District 1 Bedroom! In unit Laundry, Close to CTA, UIC',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-medical-district-bedroom-in/7577179735.html',
#   'price': '$2,030',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Medical District',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'REHABBED 3 Bed 2 Bath in Southport Corridor!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-rehabbed-bed-bath-in-southport/7577170056.html',
#   'price': '$3,600',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'BRAND NEW 3 BED 2 BATH IN THE HEART OF PALMER SQAURE',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-brand-new-bed-bath-in-the-heart/7577167597.html',
#   'price': '$2,990',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Palmer Square',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Sunny Lake View apt near Red Line!, On-Site W/D, Central A/C',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-sunny-lake-view-apt-near-red/7577160229.html',
#   'price': '$3,100',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'South Loop Luxury 2 Bedroom Apartment in Printers Row',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-south-loop-luxury-bedroom/7577157288.html',
#   'price': '$2,993',
#   'bedroom': '2br',
#   'sqft': '1158',
#   'neighborhood': 'city of chicago',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'River North 1-Bed with amazing amenities! Red Line, Location and Food.',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-river-north-bed-with-amazing/7577140424.html',
#   'price': '$2,155',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'River North',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Massive 2-Bedroom Loft. Condo Quality Units, CTA and Great Location.',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-massive-bedroom-loft-condo/7577133451.html',
#   'price': '$2,485',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Uptown',
#   'bathroom': '2.5',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Prepare to live in luxury at Residences at Arlington Heights! Call us today!',
#   'link': 'https://chicago.craigslist.org/nwc/apa/d/arlington-heights-prepare-to-live-in/7577132378.html',
#   'price': '$1,665',
#   'bedroom': '2br',
#   'sqft': '864',
#   'neighborhood': 'Arlington Heights',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d hookups',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Stunning 1 Bedroom, 1 Bath in Lakeview, Available: 3/1/2023',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-stunning-bedroom-bath-in/7577124657.html',
#   'price': '$1,795',
#   'bedroom': '1br',
#   'sqft': '700',
#   'neighborhood': 'Lakeview',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Logan Sq. Two Bedroom Plus Office in Quiet Building',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-logan-sq-two-bedroom-plus/7577123906.html',
#   'price': '$1,500',
#   'bedroom': '2br',
#   'sqft': '1000',
#   'neighborhood': 'Chicago',
#   'bathroom': '1',
#   'amenities': ['application fee details: $60',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'no parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Praiseworthy 1 Bedroom, 1 Bath in Lincoln Park, Available: Now',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-praiseworthy-bedroom-bath-in/7577122641.html',
#   'price': '$1,850',
#   'bedroom': '1br',
#   'sqft': '700',
#   'neighborhood': 'Lincoln Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Heavenly 1 Bedroom, 1 Bath in Lincoln Park, Available: Now',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-heavenly-bedroom-bath-in/7577122197.html',
#   'price': '$1,850',
#   'bedroom': '1br',
#   'sqft': '700',
#   'neighborhood': 'Lincoln Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Unbelievably Sharp 3 Bedroom, 1 Bath in Roscoe Village, Available: 2/1/2023',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-unbelievably-sharp-bedroom-bath/7577120829.html',
#   'price': '$2,795',
#   'bedroom': '3br',
#   'sqft': '1500',
#   'neighborhood': 'Roscoe Village',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Great Location! 1/1, W/D, River North, Pool, Fitness Center, CTA.',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-great-location-1-d-river-north/7577120219.html',
#   'price': '$2,240',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'River North',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '3 Bed/2Bath Duplex~ Central Heat/AC~ In Unit Washer/Dryer! Deck!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-bed-2bath-duplex-central-heat/7577120108.html',
#   'price': '$3,490',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'East Lakeview/Wrigleyville',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'carport',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Gorgeous Convertible 1-Bed Logan Square! Great Location, New Building',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-gorgeous-convertible-bed-logan/7577119715.html',
#   'price': '$1,845',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Logan Square',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '3BD 1BA Apartment Available 03/27! Amazing Price & Amazing Location!!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-3bd-1ba-apartment-available/7577118865.html',
#   'price': '$2,750',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'city of chicago',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '1br - 315ft2 - Woodspring Suites, New Guest Check In Special Going FAS',
#   'link': 'https://chicago.craigslist.org/sox/apa/d/tinley-park-1br-315ft2-woodspring/7577118795.html',
#   'price': '$1,200',
#   'bedroom': '1br',
#   'sqft': '315',
#   'neighborhood': 'Tinley Park',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'furnished',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': 'Jan 10',
#   'title': 'Want Amenities? It has it ALL! LUXXXE Lakeview/Boystown',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-want-amenities-it-has-it-all/7577116009.html',
#   'price': '$5,110',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '2',
#   'amenities': ['EV charging',
#    'air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': 'Jan 10',
#   'title': 'Spacious 2-Bed South Loop. Luxury Amenities and Great Location!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-spacious-bed-south-loop-luxury/7577114211.html',
#   'price': '$2,610',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'South Loop',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Gorgeous 1-Bedroom in courtyard building on a quiet tree lined street!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-gorgeous-bedroom-in-courtyard/7577113912.html',
#   'price': '$1,725',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'East Lakeview',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Western-Peterson, Heated  2-bed condo',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-western-peterson-heated-bed/7577113554.html',
#   'price': '$1,450',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Arcadia terrace, 5900 N. and 2400 W.',
#   'bathroom': '1',
#   'amenities': ['application fee details: $40 credit ck',
#    'cats are OK - purrr',
#    'condo',
#    'laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Lakeview Gem! Renovated Studio 1-Bath Available 04/03/2023!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-lakeview-gem-renovated-studio/7577113492.html',
#   'price': '$1,400',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'East Lakeview',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Cute Old Town Studio! Central Air, Granite, Gym, CTA, 24 hr doorman',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-cute-old-town-studio-central/7577110483.html',
#   'price': '$1,670',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Old Town',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '**Re-Let**  Beautiful Two  Bedroom Units@ Oak Park',
#   'link': 'https://chicago.craigslist.org/wcl/apa/d/oak-park-re-let-beautiful-two-bedroom/7577106849.html',
#   'price': '$1,915',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Fountainhead Apartments',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '1 Bedroom Condo',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-bedroom-condo/7577104223.html',
#   'price': '$1,300',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Chicago',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'no parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Uptown XLStudio,brand new Dishwasher, stunning Lake and Skyline views',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-uptown-xlstudiobrand-new/7577096660.html',
#   'price': '$1,000',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview,Lincoln Park,Edgewater,Andersonville,DePaul,Loyola',
#   'bathroom': '1',
#   'amenities': ['open house dates',
#    'tuesday 2023-01-10',
#    'wednesday 2023-01-11',
#    'thursday 2023-01-12']},
#  {'date': 'Jan 10',
#   'title': 'YOUR NEW BEAUTIFUL SMALL FAMILY HOUSE',
#   'link': 'https://chicago.craigslist.org/nwi/apa/d/hammond-your-new-beautiful-small-family/7577095405.html',
#   'price': '$1,050',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Hammond',
#   'bathroom': '1',
#   'amenities': ['sunday 2023-01-15']},
#  {'date': 'Jan 10',
#   'title': 'SECTION 8 VOUCHER WELCOME Beautiful fully renovated single family home',
#   'link': 'https://chicago.craigslist.org/nwc/apa/d/bolingbrook-section-voucher-welcome/7577076222.html',
#   'price': '$4,662',
#   'bedroom': '6br',
#   'sqft': '1900',
#   'neighborhood': 'Bolingbrook, IL',
#   'bathroom': '3',
#   'amenities': ['air conditioning',
#    'house',
#    'w/d hookups',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '2bedroom/ 2 bath Renovated Apartment Andersonville !',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-2bedroom-bath-renovated/7577088826.html',
#   'price': '$1,875',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Andersonville Chicago',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful Grand Studio in Bucktown!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-beautiful-grand-studio-in/7577087050.html',
#   'price': '$1,800',
#   'bedroom': '0br',
#   'sqft': '602',
#   'neighborhood': 'Bucktown',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Large 2 bedroom! Location! Location!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-large-bedroom-location-location/7577083591.html',
#   'price': '$1,655',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Buena Park Chicago',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Bright 1 bd apartment available now w/skyline view',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-bright-bd-apartment-available/7577081331.html',
#   'price': '$2,575',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Chicago',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '3 Bed 2 Bath Duplex In Southport Corridor',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-bed-bath-duplex-in-southport/7577080238.html',
#   'price': '$3,600',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Unique update Lakeview 1 bedroom',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-unique-update-lakeview-bedroom/7577076983.html',
#   'price': '$1,670',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Simply Beautiful! Central Lakeview Location!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-simply-beautiful-central/7577074141.html',
#   'price': '$2,597',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'HEAT INCLUDED! Renovated Lakeview Studio!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-heat-included-renovated/7577073897.html',
#   'price': '$1,500',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'BUENA PARK RENOVATED STUDIO, H/W GAS AND HEAT INCLUDED GREAT LOCATION!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-buena-park-renovated-studio-w/7577072295.html',
#   'price': '$1,050',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Buena Park / Lakeview',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'ANDERSONVILLE: 4 BED 3 BATH DUPLEX CONDO QUARTZ STAINLESS LAUNDRY IN UNIT',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-andersonville-bed-bath-duplex/7577072063.html',
#   'price': '$2,995',
#   'bedroom': '4br',
#   'sqft': nan,
#   'neighborhood': 'Andersonville',
#   'bathroom': '4.5',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'LAKEVIEW: 3 BED 3 BATH REHAB S/S APPS W/ DW HDWD GAS FIREPLACE W/D',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-lakeview-bed-bath-rehab-s-apps/7577071927.html',
#   'price': '$2,500',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '3',
#   'amenities': ['condo',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Ravenswood 2023 Rehab 1 bedroom!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-ravenswood-2023-rehab-bedroom/7577069719.html',
#   'price': '$2,100',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Ravenswood Chicago',
#   'bathroom': '1.5',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'High-End 2 Bed 2 Bath River North Luxury Apartment',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-high-end-bed-bath-river-north/7577067513.html',
#   'price': '$3,107',
#   'bedroom': '2br',
#   'sqft': '1320',
#   'neighborhood': 'city of chicago',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '2Bedroom APT in Gage Park',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-2bedroom-apt-in-gage-park/7577065302.html',
#   'price': '$1,100',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Gage Park',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'no laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Your perfect home is waiting!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-your-perfect-home-is-waiting/7577062493.html',
#   'price': '$975',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Chicago Lawn, Chicago',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'South Suburbs 3 bedroom house for rent',
#   'link': 'https://chicago.craigslist.org/sox/apa/d/dolton-south-suburbs-bedroom-house-for/7577060834.html',
#   'price': '$2,200',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Dolton',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'application fee details: $35',
#    'house',
#    'w/d hookups',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Brand New Studio! W/D in-unit, Red-Line, 9 Ft. Ceilings, Gym!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-brand-new-studio-d-in-unit-red/7577060486.html',
#   'price': '$1,407',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Uptown',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Gorgeous Rehabbed Unit! Prime Lakeview/Lincoln Park Location!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-gorgeous-rehabbed-unit-prime/7577059895.html',
#   'price': '$1,795',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'HEAT INCLUDED! Lovely Lincoln Park/Lakeview Area!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-heat-included-lovely-lincoln/7577057791.html',
#   'price': '$1,500',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Lakeview',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '1464 S Michigan Ave Condo For Rent',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-1464-michigan-ave-condo-for-rent/7577055169.html',
#   'price': '$2,000',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Chicago',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Amazing 2 Bedroom, Gold Coast, Exposed Brick, Pets Ok, Red Line!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-amazing-bedroom-gold-coast/7577053498.html',
#   'price': '$2,095',
#   'bedroom': '2br',
#   'sqft': '900',
#   'neighborhood': 'Gold Coast',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Enjoy our views of lush landscaping and beautiful courtyards',
#   'link': 'https://chicago.craigslist.org/nwc/apa/d/arlington-heights-enjoy-our-views-of/7577053052.html',
#   'price': '$2,095',
#   'bedroom': '3br',
#   'sqft': '1128',
#   'neighborhood': 'Arlington Heights',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Easy Access To The Train! Heat Included! Updated Kitchen! Ready Now!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-easy-access-to-the-train-heat/7577050840.html',
#   'price': '$1,450',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Old Irving Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'River North 1 bedroom with balcony',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-river-north-bedroom-with-balcony/7577049835.html',
#   'price': '$2,188',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'River North',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'River North Studio, washer/dryer, 24hr security, excellent walkability',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-river-north-studio-washer-dryer/7577049606.html',
#   'price': '$1,800',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'River North',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '4 beds available in a nice place',
#   'link': 'https://chicago.craigslist.org/wcl/apa/d/maywood-beds-available-in-nice-place/7577048922.html',
#   'price': '$1,900',
#   'bedroom': '4br',
#   'sqft': nan,
#   'neighborhood': '15th Ave, Maywood',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'townhouse',
#    'no laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Great Located 2 Bedroom, Wrigleyville, Central Air, Pets Ok  2/1/2023',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-great-located-bedroom/7577048498.html',
#   'price': '$1,895',
#   'bedroom': '2br',
#   'sqft': '900',
#   'neighborhood': 'Wrigleyville',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'West loop 1 bedroom, lots of light, w/d in unit',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-west-loop-bedroom-lots-of-light/7577046280.html',
#   'price': '$2,295',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'West Loop',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '4bed/2bath, DUPLEX UP, near CTA BLUE line, laundry room, deck space',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-4bed-2bath-duplex-up-near-cta/7577045173.html',
#   'price': '$3,175',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Chicago - Logan Square',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '3bed/2bath 2 level Coach House, near shopping and entertainment',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-3bed-2bath-level-coach-house/7577044770.html',
#   'price': '$2,435',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Lincoln Park - Bucktown',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Amazing Located Studio,  Ravenswood, Close to EL, Pets Ok  2/1/2023',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-amazing-located-studio/7577043911.html',
#   'price': '$1,195',
#   'bedroom': '0br',
#   'sqft': '400',
#   'neighborhood': 'Ravenswood',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'HUGE Vintage Logan Square 2 bed, Sep Dining Rm 3/1/23',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-huge-vintage-logan-square-bed/7577042283.html',
#   'price': '$2,095',
#   'bedroom': '2br',
#   'sqft': '1443',
#   'neighborhood': 'Logan Square',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'WINTER SPECIAL! Cozy Renovated 2Bd/1Bth Unit',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-winter-special-cozy-renovated/7577041227.html',
#   'price': '$1,400',
#   'bedroom': '2br',
#   'sqft': '800',
#   'neighborhood': 'Humboldt Park',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'application fee details: $25 Application and Background',
#    'apartment',
#    'w/d hookups',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Extra Large Jumbo Lincoln Park Studio! HEAT INCLUDED!!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-extra-large-jumbo-lincoln-park/7577039235.html',
#   'price': '$1,425',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Lincoln Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'UKRAINIAN VILLAGE TWO  BEDROOM REHAB, SUNNY DECK, IN UNIT LAUNDRY!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-ukrainian-village-two-bedroom/7577038930.html',
#   'price': '$1,550',
#   'bedroom': '2br',
#   'sqft': '900',
#   'neighborhood': 'Wicker Park',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '3bed/2bath elevator, CTA, Lake, GYM, dishwasher, A/C, rooftop',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-3bed-2bath-elevator-cta-lake/7577037675.html',
#   'price': '$2,724',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Uptown',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'street parking',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': 'Jan 10',
#   'title': 'Recently Remodeled Studio (Chicago-East Rogers Park)',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-recently-remodeled-studio/7577034193.html',
#   'price': '$825',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': '1234 W Loyola',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Large Evanston Duplex Apt.',
#   'link': 'https://chicago.craigslist.org/nch/apa/d/evanston-large-evanston-duplex-apt/7577033631.html',
#   'price': '$2,100',
#   'bedroom': '2br',
#   'sqft': '1250',
#   'neighborhood': 'Evanston, IL',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'application fee details: $25',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful  Two Bedroom Units @ Lotus Garden Apartments - Skokie',
#   'link': 'https://chicago.craigslist.org/wcl/apa/d/skokie-beautiful-two-bedroom-units/7577032072.html',
#   'price': '$1,500',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': '8538 N Lotus - Skokie',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'NEW Rehab 1 Bedroom, Lincoln Park, InUnit Laundry, Pets OK',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-new-rehab-bedroom-lincoln-park/7577031265.html',
#   'price': '$1,850',
#   'bedroom': '1br',
#   'sqft': '700',
#   'neighborhood': 'Lincoln Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Gorgeous 2 Bedroom, 2 Bath Gold Coast, Balcony, Pets OK',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-gorgeous-bedroom-bath-gold/7577030339.html',
#   'price': '$2,495',
#   'bedroom': '2br',
#   'sqft': '900',
#   'neighborhood': 'Gold Coast',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful and Spacious 2 BR/2BA Condo for rent!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-beautiful-and-spacious-br-2ba/7577029235.html',
#   'price': '$1,600',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'North Ravenswood/West Ridge',
#   'bathroom': '2',
#   'amenities': ['application fee details: $30 per renter. Application processing and background check',
#    'cats are OK - purrr',
#    'condo',
#    'w/d in unit',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Medical District - UIC ! Brand New 1-Bedroom. Gym, Pool and Rooftop.',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-medical-district-uic-brand-new/7577029220.html',
#   'price': '$2,025',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Medical District',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful  Two Bedroom Apartments   @ Garden House Apartments',
#   'link': 'https://chicago.craigslist.org/nch/apa/d/skokie-beautiful-two-bedroom-apartments/7577028320.html',
#   'price': '$1,550',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Skokie',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful One   Bedroom Apts @10737 S Keating',
#   'link': 'https://chicago.craigslist.org/sox/apa/d/oak-lawn-beautiful-one-bedroom-apts/7577028015.html',
#   'price': '$1,350',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Oak Lawn',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful One   Bedroom Units @ 1644 W. Sherwin',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-beautiful-one-bedroom-units/7577027333.html',
#   'price': '$1,350',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'East Rogers Park',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful Two   Bedroom Apartments @ 810 Seward',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/evanston-beautiful-two-bedroom/7577026016.html',
#   'price': '$1,425',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': '810 Seward - Evanston',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '216 N. May St. Unit 101',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-216-may-st-unit-101/7577025821.html',
#   'price': '$3,395',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'West Loop',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Top Floor W/Lake & City Views! Heat & Gas Included! Parking Available!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-top-floor-lake-city-views-heat/7577025192.html',
#   'price': '$1,350',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'East Lakeview',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Brand New Bright Sunny Modern Unit in Pilsen!! Steps to Pink Line',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-brand-new-bright-sunny-modern/7577024259.html',
#   'price': '$1,525',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Pilsen',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'APARTMENT FOR RENT',
#   'link': 'https://chicago.craigslist.org/sox/apa/d/chicago-apartment-for-rent/7577024165.html',
#   'price': '$900',
#   'bedroom': '1br',
#   'sqft': '800',
#   'neighborhood': 'MIDWAY AIRPORT',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'apartment',
#    'laundry in bldg',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Medical District - UIC ! Brand New 2-Bedroom. Gym, Pool and Rooftop.',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-medical-district-uic-brand-new/7577020355.html',
#   'price': '$2,275',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Medical District',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Brand New Studio! W/D in-unit, Medical District/UIC, Pool, Gym!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-brand-new-studio-d-in-unit/7577019776.html',
#   'price': '$1,500',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Medical District',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Garden Apartment  for rent Little Italy location',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-garden-apartment-for-rent/7577019136.html',
#   'price': '$1,200',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'little Italy',
#   'bathroom': '1.5',
#   'amenities': ['apartment',
#    'w/d in unit',
#    'no parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '1238 N. Noble Unit 1',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-1238-noble-unit/7577018760.html',
#   'price': '$4,195',
#   'bedroom': '5br',
#   'sqft': nan,
#   'neighborhood': 'Wicker Park',
#   'bathroom': '5',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'w/d in unit',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Location! Heat Included! Dishwasher! Dog Friendly! Ready Now!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-location-heat-included/7577016239.html',
#   'price': '$1,100',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'South Old Irving Park/Kilbourn Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Luxury West Loop Studio, 30th floor views! Washer/dryer, available now',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-luxury-west-loop-studio-30th/7577015876.html',
#   'price': '$2,075',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'West Loop',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Berwyn studio in vintage Building',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/berwyn-berwyn-studio-in-vintage-building/7577014872.html',
#   'price': '$825',
#   'bedroom': '0br',
#   'sqft': '300',
#   'neighborhood': 'South Berwyn',
#   'bathroom': '1',
#   'amenities': ['application fee details: $50.00',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '3 Bedroom 2 bathroom Condo Quality',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-bedroom-bathroom-condo-quality/7577009858.html',
#   'price': '$2,100',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Chicago, IL',
#   'bathroom': '2',
#   'amenities': ['air conditioning',
#    'application fee details: $50',
#    'cats are OK - purrr',
#    'apartment',
#    'w/d hookups',
#    'no smoking',
#    'carport',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '3 BED 2.5 BATH DUPLEX DOWN IN WICKER PARK',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-bed-25-bath-duplex-down-in/7577009682.html',
#   'price': '$3,715',
#   'bedroom': '3br',
#   'sqft': '2000',
#   'neighborhood': 'TONS OF SPACE!',
#   'bathroom': '2.5',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'condo',
#    'w/d in unit',
#    'detached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Affordability in Downtown Evanston!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/evanston-affordability-in-downtown/7576991440.html',
#   'price': '$1,715',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Evanston',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '***SPACIOUS 1-BED BRICK AND TIMBER LOFT; PETS OK! ROOFTOP DECK!***',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-spacious-bed-brick-and-timber/7576990320.html',
#   'price': '$2,070',
#   'bedroom': '1br',
#   'sqft': '696',
#   'neighborhood': 'Pilsen',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Location! Heat Included! Large Floorplan! Outdoor Space Ready Now!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-location-heat-included-large/7576988287.html',
#   'price': '$1,100',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'South Old Irving Park/Kilbourn Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Pilsen Bright and Spacious 2bed on Top Floor! - In Unit Laundry',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-pilsen-bright-and-spacious-2bed/7576984487.html',
#   'price': '$1,400',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Pilsen',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'LOGAN SQUARE Cozy 1 bed+ office',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-logan-square-cozy-bed-office/7576984026.html',
#   'price': '$1,275',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Chicago',
#   'bathroom': '1',
#   'amenities': ['application fee details: $40 per applicant',
#    'cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Cozy 1B apartment available March!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-cozy-1b-apartment-available/7576981418.html',
#   'price': '$1,615',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Chicago',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Studio available in Gold Coast!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-studio-available-in-gold-coast/7576981198.html',
#   'price': '$1,315',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Chicago',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful  Studio  Apartments   @ Garden House Apartments',
#   'link': 'https://chicago.craigslist.org/nch/apa/d/skokie-beautiful-studio-apartments/7576980138.html',
#   'price': '$1,000',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Skokie',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Extra Large Jumbo Lincoln Park Studio!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-extra-large-jumbo-lincoln-park/7576979468.html',
#   'price': '$1,425',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'Lincoln Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Location! Heat & Gas Included! Large Floorplan! Small Dog Ok! Ready!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-location-heat-gas-included/7576979328.html',
#   'price': '$1,150',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Rogers Park',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful Two  Bedroom Units@ Oak Park',
#   'link': 'https://chicago.craigslist.org/wcl/apa/d/oak-park-beautiful-two-bedroom-units/7576977659.html',
#   'price': '$1,950',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Fountainhead Apartments',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Quite, Clean, Secure 1-bedroom 312-953-0785',
#   'link': 'https://chicago.craigslist.org/sox/apa/d/chicago-quite-clean-secure-bedroom/7576977165.html',
#   'price': '$950',
#   'bedroom': '1br',
#   'sqft': '850',
#   'neighborhood': 'Marquette Park, Free Heat',
#   'bathroom': '1',
#   'amenities': ['application fee details: $50 Credit and Backround check',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful Studio - Apartments @7425 S South Shore - Available Now',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-beautiful-studio-apartments/7576974474.html',
#   'price': '$850',
#   'bedroom': '0br',
#   'sqft': nan,
#   'neighborhood': 'South Shore Neighborhood',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful One Bedroom - Apartments @7425 S South Shore - Available NOW',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-beautiful-one-bedroom/7576973919.html',
#   'price': '$1,150',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'South Shore Neighborhood',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful  One   Bedrooms (Chicago-West Pullman )',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-beautiful-one-bedrooms-chicago/7576973647.html',
#   'price': '$950',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': '11941 S Parnell',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'no laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful Two   Bedroom Apts @10737 S Keating',
#   'link': 'https://chicago.craigslist.org/sox/apa/d/oak-lawn-beautiful-two-bedroom-apts/7576973046.html',
#   'price': '$1,650',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Oak Lawn',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Amazing Three    Bedroom Apartments  @Willard Square Apartments',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-amazing-three-bedroom/7576972624.html',
#   'price': '$1,426',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': 'Chicago',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'no smoking',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Renovated Loft Apartment with Central AC, Dishwasher (2001H-3R)',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-renovated-loft-apartment-with/7576970384.html',
#   'price': '$1,485',
#   'bedroom': '0br',
#   'sqft': '763',
#   'neighborhood': 'East Pilsen',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'application fee details: $40.00',
#    'cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'no smoking',
#    'off-street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'South Shore Condo with Lake Views',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/south-shore-condo-with-lake-views/7576969571.html',
#   'price': '$1,400',
#   'bedroom': '2br',
#   'sqft': '1200',
#   'neighborhood': '7337 South Shore Drive Unit1415',
#   'bathroom': '1',
#   'amenities': ['air conditioning',
#    'application fee details: $40 application fee per adult',
#    'condo',
#    'laundry in bldg',
#    'attached garage',
#    'rent period: monthly',
#    'wheelchair accessible']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful Three   Bedroom Units @ Dr. King Legacy Apartments',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-beautiful-three-bedroom-units/7576969024.html',
#   'price': '$1,200',
#   'bedroom': '3br',
#   'sqft': nan,
#   'neighborhood': '1550 S Hamlin ( North Lawndale)',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': '**Re-Let**  Beautiful One  Bedroom Units@ Oak Park',
#   'link': 'https://chicago.craigslist.org/wcl/apa/d/oak-park-re-let-beautiful-one-bedroom/7576968444.html',
#   'price': '$1,430',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Fountainhead Apartments',
#   'bathroom': '1',
#   'amenities': ['apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Location! Heat Included! Hardwood Floors! Small Dog Ok! Ready Now!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-location-heat-included-hardwood/7576967765.html',
#   'price': '$1,000',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': 'Mayfair',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'LOYOLA BEACH  4 BED 2 BATH  TOP FLOOR',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-loyola-beach-bed-bath-top-floor/7576967700.html',
#   'price': '$3,300',
#   'bedroom': '4br',
#   'sqft': nan,
#   'neighborhood': 'Rogers Park',
#   'bathroom': '2',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'w/d in unit',
#    'attached garage',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Rare Lincoln Square Jr One bedroom!',
#   'link': 'https://chicago.craigslist.org/chc/apa/d/chicago-rare-lincoln-square-jr-one/7576966561.html',
#   'price': '$1,395',
#   'bedroom': '1br',
#   'sqft': '550',
#   'neighborhood': 'Lincoln Square',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry in bldg',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Spacious Apartments -One, Two, Three -Itasca, Il',
#   'link': 'https://chicago.craigslist.org/nwc/apa/d/medinah-spacious-apartments-one-two/7576966382.html',
#   'price': '$1,460',
#   'bedroom': '2br',
#   'sqft': nan,
#   'neighborhood': 'Colonial Village Apartments -1640 Norwood Ave',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'dogs are OK - wooof',
#    'apartment',
#    'laundry on site',
#    'street parking',
#    'rent period: monthly']},
#  {'date': 'Jan 10',
#   'title': 'Beautiful  One  Bedroom Units @ Lotus Garden Apartments - Skokie',
#   'link': 'https://chicago.craigslist.org/wcl/apa/d/skokie-beautiful-one-bedroom-units/7576965273.html',
#   'price': '$1,300',
#   'bedroom': '1br',
#   'sqft': nan,
#   'neighborhood': '8538 N Lotus - Skokie',
#   'bathroom': '1',
#   'amenities': ['cats are OK - purrr',
#    'apartment',
#    'laundry on site',
#    'off-street parking',
#    'rent period: monthly']}]

# %%
# creating DataFrame
df = pd.DataFrame(datatoget)
df
# Out:
#        date                                              title  \
# 0    Jan 10            Brighton Park Studio Apartment for Rent
# 1    Jan 10                           South Oak Park Apartment
# 2    Jan 10                      1 Bedroom House Near Griffith
# 3    Jan 10  GORGEOUS 1 Bedroom in West Loop! W/D in Unit, ...
# 4    Jan 10           All new renovation! Ample natural light!
# ..      ...                                                ...
# 115  Jan 10  Location! Heat Included! Hardwood Floors! Smal...
# 116  Jan 10              LOYOLA BEACH  4 BED 2 BATH  TOP FLOOR
# 117  Jan 10                Rare Lincoln Square Jr One bedroom!
# 118  Jan 10   Spacious Apartments -One, Two, Three -Itasca, Il
# 119  Jan 10  Beautiful  One  Bedroom Units @ Lotus Garden A...
#
#                                                   link   price bedroom  sqft  \
# 0    https://chicago.craigslist.org/chc/apa/d/chica...    $675     0br   600
# 1    https://chicago.craigslist.org/nwc/apa/d/oak-p...  $1,800     3br  1500
# 2    https://chicago.craigslist.org/nwi/apa/d/gary-...    $925     1br   750
# 3    https://chicago.craigslist.org/chc/apa/d/chica...  $2,260     1br   NaN
# 4    https://chicago.craigslist.org/chc/apa/d/chica...  $1,050     0br   500
# ..                                                 ...     ...     ...   ...
# 115  https://chicago.craigslist.org/chc/apa/d/chica...  $1,000     1br   NaN
# 116  https://chicago.craigslist.org/chc/apa/d/chica...  $3,300     4br   NaN
# 117  https://chicago.craigslist.org/chc/apa/d/chica...  $1,395     1br   550
# 118  https://chicago.craigslist.org/nwc/apa/d/medin...  $1,460     2br   NaN
# 119  https://chicago.craigslist.org/wcl/apa/d/skoki...  $1,300     1br   NaN
#
#                                       neighborhood bathroom  \
# 0                            Brighton Park Chicago        1
# 1                                         Oak Park        1
# 2                        Griffith/Calumet Township        1
# 3                                        West Loop        1
# 4                                         Lakeview        1
# ..                                             ...      ...
# 115                                        Mayfair        1
# 116                                    Rogers Park        2
# 117                                 Lincoln Square        1
# 118  Colonial Village Apartments -1640 Norwood Ave        1
# 119                          8538 N Lotus - Skokie        1
#
#                                              amenities
# 0    [application fee details: Application fee for ...
# 1    [apartment, laundry in bldg, detached garage, ...
# 2    [air conditioning, house, w/d hookups, off-str...
# 3    [cats are OK - purrr, dogs are OK - wooof, apa...
# 4    [air conditioning, cats are OK - purrr, apartm...
# ..                                                 ...
# 115  [cats are OK - purrr, dogs are OK - wooof, apa...
# 116  [cats are OK - purrr, dogs are OK - wooof, apa...
# 117  [cats are OK - purrr, apartment, laundry in bl...
# 118  [cats are OK - purrr, dogs are OK - wooof, apa...
# 119  [cats are OK - purrr, apartment, laundry on si...
#
# [120 rows x 9 columns]

# %%
# Exporting data to csv
df.to_csv(f"{city}_data_raw.csv", index=False)
